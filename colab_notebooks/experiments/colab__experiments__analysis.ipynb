# %% [markdown]
# # Подготовка данных

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import ast
import pandas as pd
import numpy as np
import math

class Experiment:
    def __init__(self, df, method):
        self.df = df
        self.method = method

    def add_probas(self, df_langproba, dropped_cols):
        self.df.drop(columns=df_langproba.columns, errors='ignore', inplace=True)
        self.df = pd.concat([self.df, df_langproba.drop(columns=dropped_cols)], axis=1)
        self.fillna_0()

    def fillna_0(self):
        new_cols = self.df.filter(regex=self.method).select_dtypes(include=['float64']).columns

        self.df[new_cols] = self.df[new_cols].fillna(0)

    def visualize_probas(self, target_col='manual_tag'):
        sns.set()

        fig, axes = plt.subplots(1, 2,figsize=(10,5))
        axes = axes.flatten()

        sns.set(style='whitegrid')

        sns.scatterplot(ax=axes[0], data=self.df, x=f'{self.method}__kaz', y=f'{self.method}__rus', hue=target_col)

        sns.kdeplot(ax=axes[1], data=self.df[[f'{self.method}__kaz', f'{self.method}__rus']])

        fig.suptitle(self.method)

    def save_experiment(self, path):
        self.df.to_csv(path, index=False)

def visualize_tags(df, method, manual_col='manual_tag', x_lang='kaz', y_lang='rus'):
    sns.set()

    nrows = math.ceil(len(df[manual_col].unique())/2)

    fig, axes = plt.subplots(nrows, 2, sharex=True, sharey=True,figsize=(10,nrows*5))
    axes = axes.flatten()

    sns.set(style='whitegrid')

    for i, tag in enumerate(df[manual_col].unique()):
        sns.scatterplot(ax=axes[i], data=df[df[manual_col]==tag], x=f'{method}__{x_lang}', y=f'{method}__{y_lang}')
        axes[i].set_title(tag)

    plt.tight_layout(pad=6.0)

    fig.suptitle(f'Распределение вероятностей для казахского (x) и русского (y), полученных с помощью метода {method}, для каждого "ручного" тега')

# %%
def sort_labels(lst):
    order = {
        'kz': 0,
        'skz': 1,
        'ru': 2,
        'unk': 3,
    }
    return sorted(lst, key=order.get)

# %%
# датасет KazRusCSW-G-D
df = pd.read_csv(
    'https://docs.google.com/spreadsheets/d/' +
    '1pIV0z6GWbt_xTweBXHIUXmU4K-84XiTseFbobv7K_xE' +
    '/export?gid=1459857604&format=csv'
)
exprmnt = Experiment(df=df, method='analysis')

# устанавливаем веса
# нам нужно убрать все теги, которые не включают казахский или русский, и при этом нам очень важно не потерять тексты с CSW
choices = [
    exprmnt.df['manual_tag'].str.contains('^kz-ru'),
    exprmnt.df['manual_tag']== 'unk'
]

conditions = [
    1,
    -1
]
exprmnt.df['weight'] = np.select(choices, conditions, default=0)

exprmnt.df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9699 entries, 0 to 9698
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   extended_text               9699 non-null   object
#  1   text                        9699 non-null   object
#  2   manual_tag                  9699 non-null   object
#  3   cld2__all_langs             9699 non-null   object
#  4   cld2__best_lang             9699 non-null   object
#  5   cld2__kaz                   9699 non-null   float64
#  6   cld2__rus                   9699 non-null   float64
#  7   cld3__best_lang             9699 non-null   object
#  8   cld3__kaz                   9699 non-null   float64
#  9   cld3__rus                   9699 non-null   float64
#  10  langid__best_lang           9699 non-null   object
#  11  langid__kaz                 9699 non-null   float64
#  12  langid__rus                 9699 non-null   float64
#  13  lingua__best_lang           9699 non-null   object
#  14  lingua__kaz                 9699 non-null   float64
#  15  lingua__rus                 9699 non-null   float64
#  16  lingua__langs               9699 non-null   object
#  17  lingua__all_langs           9699 non-null   object
#  18  mediapipe__best_lang        9699 non-null   object
#  19  mediapipe__kaz              9699 non-null   float64
#  20  mediapipe__rus              9636 non-null   float64
#  21  fast_langdetect__best_lang  9699 non-null   object
#  22  fast_langdetect__kaz        9699 non-null   float64
#  23  fast_langdetect__rus        9699 non-null   float64
#  24  glotlid__best_lang          9699 non-null   object
#  25  glotlid__kaz                9699 non-null   float64
#  26  glotlid__rus                9699 non-null   float64
#  27  fasttext__best_lang         9699 non-null   object
#  28  fasttext__kaz               9699 non-null   float64
#  29  fasttext__rus               9699 non-null   float64
#  30  tokens                      9699 non-null   object
#  31  spans                       9699 non-null   object
#  32  n_tokens                    9699 non-null   int64
#  33  dict__best_lang             9699 non-null   object
#  34  dict__token_annot           9699 non-null   object
#  35  dict__unk                   9699 non-null   float64
#  36  dict__kaz                   9699 non-null   float64
#  37  dict__ambig                 9699 non-null   float64
#  38  dict__rus                   9699 non-null   float64
#  39  weight                      9699 non-null   int64
# dtypes: float64(20), int64(2), object(18)
# memory usage: 3.0+ MB

# %%
exprmnt.df.groupby(['weight', 'manual_tag'])['text'].count()
# Out:
# weight  manual_tag
# -1      unk             43
#  0      kz            3158
#         kz-unk         113
#         ru            5407
#         ru-unk          71
#         skz            174
#         skz-ru         187
#         skz-ru-unk       3
#         skz-unk          4
#  1      kz-ru          523
#         kz-ru-unk       16
# Name: text, dtype: int64

# %%
# распределение ручных тегов
df['manual_tag'].value_counts() / len(df)
# Out:
# manual_tag
# ru            0.557480
# kz            0.325601
# kz-ru         0.053923
# skz-ru        0.019280
# skz           0.017940
# kz-unk        0.011651
# ru-unk        0.007320
# unk           0.004433
# kz-ru-unk     0.001650
# skz-unk       0.000412
# skz-ru-unk    0.000309
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from sklearn.metrics import classification_report, accuracy_score, precision_recall_curve, roc_auc_score, f1_score

import pandas as pd
import numpy as np

# %%
# !pip install langcodes
# !pip install language_data
# Out:
# Collecting langcodes
#   Downloading langcodes-3.5.1-py3-none-any.whl.metadata (30 kB)
# Downloading langcodes-3.5.1-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.1/183.1 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: langcodes
# Successfully installed langcodes-3.5.1
# Collecting language_data
#   Downloading language_data-1.4.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting marisa-trie>=1.1.0 (from language_data)
#   Downloading marisa_trie-1.4.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Downloading language_data-1.4.0-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 70.2 MB/s eta 0:00:00
# Downloading marisa_trie-1.4.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 60.9 MB/s eta 0:00:00
# Installing collected packages: marisa-trie, language_data
# Successfully installed language_data-1.4.0 marisa-trie-1.4.1

# %%
from langcodes import Language

def get_lang_name(s):
    """
    Функция возвращает полное название для языкового кода
    """
    if len(s)>3:
        return s.lower()

    if s == 'kz':
        s = 'kk'
    res = Language.get(s).display_name().lower()

    if res.startswith('unknown') or s == 'unk':
        return s
    return res

# %%
# расшифровываем названия языков
cols = df.filter(regex='best_lang').columns

for c in cols:
    if c.startswith('glotlid') or c.startswith('fasttext'):
        df[c] = df[c].str.replace('__label__', '')
        df[c] = df[c].str.replace('_Cyrl', '')
    df[c] = df[c].apply(get_lang_name)

# %% [markdown]
# ## Согласованность предсказаний (Альфа Криппендорфа)

# %%
# !pip install krippendorff
# Out:
# Collecting krippendorff
#   Downloading krippendorff-0.8.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<3,>=1.21 in /usr/local/lib/python3.12/dist-packages (from krippendorff) (2.0.2)
# Downloading krippendorff-0.8.2-py3-none-any.whl (18 kB)
# Installing collected packages: krippendorff
# Successfully installed krippendorff-0.8.2

# %%
import krippendorff

# %%
from collections import defaultdict
lang2n = set()
for c in cols:
    lang2n.update(df[c].unique())
lang2n = dict(zip(lang2n, range(len(lang2n))))

# %%
lang2n_simpl = {k: 0 for k,v in lang2n.items()}
lang2n_simpl['kazakh'] = 1
lang2n_simpl['russian'] = 2

# %%
import krippendorff

data_numeric = df[df['manual_tag'].isin(['kz', 'ru', 'unk', 'skz'])][cols].replace(lang2n_simpl).values

alpha = krippendorff.alpha(
    reliability_data=data_numeric,
    level_of_measurement='nominal'
)

print(f"Альфа Криппендорфа для одноязычных текстов (теги сгруппированы): {alpha:.4f}")
# Out:
# /tmp/ipykernel_30641/1352313505.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_numeric = df[df['manual_tag'].isin(['kz', 'ru', 'unk', 'skz'])][cols].replace(lang2n_simpl).values
# Альфа Криппендорфа для одноязычных текстов (теги сгруппированы): 0.0031

# %% [markdown]
# Значение очень мало, что говорит о несогласовонности, большом разнообразии предсказаний.

# %% [markdown]
# # Эксперимент 1. Отсеивание нерелевантных текстов
#
# В данном эксперименте мы попытались проанализировать, возможно ли надежно выявлять тексты с переключением кодов с помощью существующих моделей LID. Для эксперимента мы отобрали 7 методов, поддерживающих казахский и русский языки. В дополнение мы имплементировали собственный словарный метод.

# %% [markdown]
# ## Словарный метод
#
# Ресурсы
#
# - https://github.com/kergalym/myspell-kk/tree/upstream
# - https://github.com/wooorm
# - hunspell
# - Н.Уəли, Ш.Құрманбайұлы, М.Малбақов, Р.Шойбеков жəне т.б. Қазақ  сөздігі (Қазақ тілінің біртомдық үлкен түсіндірме сөздігі). Алматы: «Дəуір» баспасы, 2013. -- соскрейплен, не публикуется

# %% [markdown]
# ### Анализ

# %%
METHOD = 'dict'

visualize_tags(exprmnt.df, method=METHOD, manual_col='manual_tag')

# %% [markdown]
# #### Q1: Для скольких одноязычных примеров (kz и ru) был правильно определен язык?

# %%
# какие теги предсказываются для текстов на казахском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))])
# Out:
# dict__best_lang
# kazakh    0.99715
# unk       0.00190
# ambig     0.00095
# Name: count, dtype: float64

# %%
# какие теги предсказываются для текстов на русском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))])
# Out:
# dict__best_lang
# russian    0.926392
# ambig      0.067135
# unk        0.005733
# kazakh     0.000740
# Name: count, dtype: float64

# %% [markdown]
# Recall для казахского значительно выше, чем для русского -- почти 1 против 0.93

# %%
sample = exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz', 'ru'])) | (exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))]
sample['manual_tag'] = sample['manual_tag'].replace({'kz': 'kazakh', 'ru': 'russian'})

print(classification_report(y_true=sample['manual_tag'], y_pred=sample[f'{METHOD}__best_lang'], labels=['kazakh', 'russian']))
# Out:
# /tmp/ipykernel_759/1325356237.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['manual_tag'] = sample['manual_tag'].replace({'kz': 'kazakh', 'ru': 'russian'})
#               precision    recall  f1-score   support
#
#       kazakh       0.86      1.00      0.92      3158
#      russian       0.92      0.93      0.92      5407
#
#    micro avg       0.90      0.95      0.92      8565
#    macro avg       0.89      0.96      0.92      8565
# weighted avg       0.90      0.95      0.92      8565

# %% [markdown]
# #### Q2: Что предсказывается для kz-ru?

# %%
counts_ = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz-ru'])].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
counts_ = (counts_ / exprmnt.df['manual_tag'].value_counts()).fillna(0)

cm = sns.light_palette("orange", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_b8a38_row0_col0 {
#   background-color: #f4ebdf;
#   color: #000000;
# }
# #T_b8a38_row1_col0 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_b8a38_row2_col0 {
#   background-color: #ffa604;
#   color: #000000;
# }
# #T_b8a38_row3_col0 {
#   background-color: #f3f0ee;
#   color: #000000;
# }
# </style>
# <table id="T_b8a38" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8a38_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="index_name level1" >dict__best_lang</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8a38_level0_row0" class="row_heading level0 row0" rowspan="4">kz-ru</th>
#       <th id="T_b8a38_level1_row0" class="row_heading level1 row0" >ambig</th>
#       <td id="T_b8a38_row0_col0" class="data row0 col0" >0.034351</td>
#     </tr>
#     <tr>
#       <th id="T_b8a38_level1_row1" class="row_heading level1 row1" >kazakh</th>
#       <td id="T_b8a38_row1_col0" class="data row1 col0" >0.484733</td>
#     </tr>
#     <tr>
#       <th id="T_b8a38_level1_row2" class="row_heading level1 row2" >russian</th>
#       <td id="T_b8a38_row2_col0" class="data row2 col0" >0.477099</td>
#     </tr>
#     <tr>
#       <th id="T_b8a38_level1_row3" class="row_heading level1 row3" >unk</th>
#       <td id="T_b8a38_row3_col0" class="data row3 col0" >0.003817</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Для csw-текстов предсказывается в основном либо казахский, либо русский, что очевидно конкретно для этого метода.

# %% [markdown]
# #### Q3: Как хорошо метод предсказывает одноязычные тексты на нерелевантных языках?

# %%
# качество бинарной классификации для определения тега unk
y_true = (exprmnt.df['manual_tag']=='unk').astype(int)
y_pred = (exprmnt.df[f'{METHOD}__best_lang']=='unk').astype(int)

print(classification_report(y_true=y_true, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      9656
#            1       0.18      0.79      0.30        43
#
#     accuracy                           0.98      9699
#    macro avg       0.59      0.89      0.64      9699
# weighted avg       1.00      0.98      0.99      9699

# %%
# какие теги предсказываются для unk
exprmnt.df[(exprmnt.df['manual_tag']=='unk')][f'{METHOD}__best_lang'].value_counts() # / len(exprmnt.df[(exprmnt.df['manual_tag']=='unk')])
# Out:
# dict__best_lang
# unk        34
# kazakh      6
# russian     2
# ambig       1
# Name: count, dtype: int64

# %%
# что предсказывается для unk, и для каких языков предсказывается unk
exprmnt.df[(exprmnt.df['manual_tag']=='unk') |(exprmnt.df[f'{METHOD}__best_lang']=='unk')].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  dict__best_lang
# kz          unk                 6
# kz-ru       unk                 2
# kz-ru-unk   unk                 1
# kz-unk      unk                 1
# ru          unk                31
# ru-unk      unk                18
# skz         unk                70
# skz-ru      unk                21
# skz-unk     unk                 2
# unk         ambig               1
#             kazakh              6
#             russian             2
#             unk                34
# Name: text, dtype: int64

# %% [markdown]
# Из всех текстов на нерелевантных языках словарный метод выявил 79% (recall=0.79).
#
# При этом 82% текстов, определенных как "нерелевантные" на самом деле содержат казахский или русский.

# %% [markdown]
# #### Q4: Какие результаты для skz?

# %%
# какие языки определены для skz
y_pred = exprmnt.df[(exprmnt.df['manual_tag']=='skz')][f'{METHOD}__best_lang']

y_pred.value_counts() / len(y_pred)
# Out:
# dict__best_lang
# kazakh    0.586207
# unk       0.402299
# ambig     0.011494
# Name: count, dtype: float64

# %%
# распределение вероятностей kaz и unk для 'skz', 'kz', 'unk'
exprmnt.df[exprmnt.df['manual_tag'].isin(['skz', 'kz', 'unk'])].groupby('manual_tag')[[f'{METHOD}__kaz', f'{METHOD}__unk']].describe().T
# Out:
# manual_tag                kz         skz        unk
# dict__kaz count  3158.000000  174.000000  43.000000
#           mean      0.872786    0.438300   0.244864
#           std       0.103660    0.177840   0.145551
#           min       0.333333    0.000000   0.000000
#           25%       0.818497    0.333333   0.142857
#           50%       0.882353    0.438262   0.222222
#           75%       0.944444    0.555556   0.353247
#           max       1.000000    1.000000   0.666667
# dict__unk count  3158.000000  174.000000  43.000000
#           mean      0.037191    0.424566   0.554192
#           std       0.065377    0.171196   0.175292
#           min       0.000000    0.000000   0.111111
#           25%       0.000000    0.333333   0.464103
#           50%       0.000000    0.400000   0.571429
#           75%       0.050794    0.500000   0.651515
#           max       0.571429    1.000000   1.000000

# %% [markdown]
# Для текстов, помеченных тегом skz (то есть написанные на "упрощенном" казахском алфавите), метод предсказывает теги kz, поскольку не все казахские слова пишутся с использованием специализированных символов, или unk -- это также очевидно для данного метода, поскольку если казахское слово написано неправильно, то оно с большой вероятностью не найдется ни в словаре казахского, ни в словаре русского языка, и будет отмечено как unk.

# %% [markdown]
# #### Q5: Что получим после фильтрации?

# %%
y_pred = exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian', 'ambig']).astype(int)

# доля тегов, которые будут выкинуты
counts_ = (exprmnt.df[y_pred==0]['manual_tag'].value_counts() / exprmnt.df['manual_tag'].value_counts()).fillna(0).rename('will_be_excluded, %')

cm = sns.light_palette("green", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_fe070_row0_col0, #T_fe070_row8_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_fe070_row1_col0, #T_fe070_row4_col0 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_fe070_row2_col0 {
#   background-color: #d8ead8;
#   color: #000000;
# }
# #T_fe070_row3_col0 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_fe070_row5_col0 {
#   background-color: #9fce9f;
#   color: #000000;
# }
# #T_fe070_row6_col0 {
#   background-color: #73b873;
#   color: #f1f1f1;
# }
# #T_fe070_row7_col0 {
#   background-color: #c9e3c9;
#   color: #000000;
# }
# #T_fe070_row9_col0 {
#   background-color: #56aa56;
#   color: #f1f1f1;
# }
# #T_fe070_row10_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fe070" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe070_level0_col0" class="col_heading level0 col0" >will_be_excluded, %</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe070_level0_row0" class="row_heading level0 row0" >kz</th>
#       <td id="T_fe070_row0_col0" class="data row0 col0" >0.001900</td>
#     </tr>
#     <tr>
#       <th id="T_fe070_level0_row1" class="row_heading level0 row1" >kz-ru</th>
#       <td id="T_fe070_row1_col0" class="data row1 col0" >0.003817</td>
#     </tr>
#     <tr>
#       <th id="T_fe070_level0_row2" class="row_heading level0 row2" >kz-ru-unk</th>
#       <td id="T_fe070_row2_col0" class="data row2 col0" >0.062500</td>
#     </tr>
#     <tr>
#       <th id="T_fe070_level0_row3" class="row_heading level0 row3" >kz-unk</th>
#       <td id="T_fe070_row3_col0" class="data row3 col0" >0.008850</td>
#     </tr>
#     <tr>
#       <th id="T_fe070_level0_row4" class="row_heading level0 row4" >ru</th>
#       <td id="T_fe070_row4_col0" class="data row4 col0" >0.005733</td>
#     </tr>
#     <tr>
#       <th id="T_fe070_level0_row5" class="row_heading level0 row5" >ru-unk</th>
#       <td id="T_fe070_row5_col0" class="data row5 col0" >0.253521</td>
#     </tr>
#     <tr>
#       <th id="T_fe070_level0_row6" class="row_heading level0 row6" >skz</th>
#       <td id="T_fe070_row6_col0" class="data row6 col0" >0.402299</td>
#     </tr>
#     <tr>
#       <th id="T_fe070_level0_row7" class="row_heading level0 row7" >skz-ru</th>
#       <td id="T_fe070_row7_col0" class="data row7 col0" >0.112903</td>
#     </tr>
#     <tr>
#       <th id="T_fe070_level0_row8" class="row_heading level0 row8" >skz-ru-unk</th>
#       <td id="T_fe070_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fe070_level0_row9" class="row_heading level0 row9" >skz-unk</th>
#       <td id="T_fe070_row9_col0" class="data row9 col0" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_fe070_level0_row10" class="row_heading level0 row10" >unk</th>
#       <td id="T_fe070_row10_col0" class="data row10 col0" >0.790698</td>
#     </tr>
#   </tbody>
# </table>

# %%
# абсолютные количества тегов, которые будут выкинуты
counts_ = exprmnt.df[y_pred==0]['manual_tag'].value_counts().rename('will_be_excluded')
counts_ = pd.concat([counts_,exprmnt.df['manual_tag'].value_counts().rename('total')], axis=1)
counts_.fillna(0)
# Out:
#             will_be_excluded  total
# manual_tag
# skz                     70.0    174
# unk                     34.0     43
# ru                      31.0   5407
# skz-ru                  21.0    186
# ru-unk                  18.0     71
# kz                       6.0   3158
# kz-ru                    2.0    524
# skz-unk                  2.0      4
# kz-ru-unk                1.0     16
# kz-unk                   1.0    113
# skz-ru-unk               0.0      3

# %% [markdown]
# ## Compact Language Detector 2
# Репозиторий: https://github.com/CLD2Owners/cld2
#
# Поддерживает 83 языка. Модель представляет собой Naïve Bayesian classifier на основе n-грамм: для казахского и русского предсказания делаются на основе квадграмм(4-грамм). В первую очередь cld2 приводит текст к нижнему регистру, удаляет цифры, пунктуацию и HTML-теги.

# %% [markdown]
# ### Анализ

# %%
METHOD = 'cld2'

visualize_tags(exprmnt.df, method=METHOD, manual_col='manual_tag')

# %%
corrections = {'skz':'kz', 'skz-ru': 'kz-ru', 'skz-ru-unk': 'kz-ru-unk', 'skz-unk': 'kz-unk'}
exprmnt.df['manual_tag_adj'] = exprmnt.df['manual_tag'].replace(corrections)
exprmnt.df['manual_tag_adj'].value_counts()
# Out:
# manual_tag_adj
# ru           5407
# kz           3332
# kz-ru         710
# kz-unk        117
# ru-unk         71
# unk            43
# kz-ru-unk      19
# Name: count, dtype: int64

# %%
# direct csw prediction
y_true = exprmnt.df['manual_tag_adj'].str.contains('kz-ru')
y_pred = exprmnt.df['cld2__all_langs'].str.contains('kz-ru')

print(classification_report(y_true=y_true, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.93      1.00      0.96      8970
#         True       0.98      0.07      0.13       729
#
#     accuracy                           0.93      9699
#    macro avg       0.96      0.53      0.55      9699
# weighted avg       0.93      0.93      0.90      9699

# %%
# какие предсказания дает cld2 для csw-текстов
df[(y_true==1) & (y_pred==0)]['cld2__all_langs'].value_counts()
# Out:
# cld2__all_langs
# ru        308
# kz        251
# unk        94
# ru-unk     17
# kz-unk      8
# Name: count, dtype: int64

# %% [markdown]
# #### Q1: Для скольких одноязычных примеров (kz и ru) был правильно определен язык?

# %%
# какие теги предсказываются для текстов на казахском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))])
# Out:
# cld2__best_lang
# kazakh    0.995883
# un        0.004117
# Name: count, dtype: float64

# %%
# какие теги предсказываются для текстов на русском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))])
# Out:
# cld2__best_lang
# russian       0.849085
# un            0.129647
# serbian       0.017385
# ukrainian     0.000925
# bulgarian     0.000925
# kyrgyz        0.000740
# kazakh        0.000370
# mongolian     0.000370
# macedonian    0.000185
# romanian      0.000185
# english       0.000185
# Name: count, dtype: float64

# %% [markdown]
# Для казахского recall значительно выше, чем для русского -- почти 1.0 против 0.85

# %%
sample = exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz', 'ru'])) | (exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].copy()
sample['manual_tag'] = sample['manual_tag'].replace({'kz': 'kazakh', 'ru': 'russian'})

print(classification_report(y_true=sample['manual_tag'], y_pred=sample[f'{METHOD}__best_lang'], labels=['kazakh', 'russian']))
# Out:
#               precision    recall  f1-score   support
#
#       kazakh       0.87      1.00      0.93      3158
#      russian       0.92      0.85      0.88      5407
#
#    micro avg       0.90      0.90      0.90      8565
#    macro avg       0.89      0.92      0.91      8565
# weighted avg       0.90      0.90      0.90      8565

# %% [markdown]
# #### Q2: Что предсказывается для kz-ru?

# %%
counts_ = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz-ru'])].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
counts_ = (counts_ / exprmnt.df['manual_tag'].value_counts()).fillna(0)

cm = sns.light_palette("orange", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_78d02_row0_col0 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_78d02_row1_col0 {
#   background-color: #feaa11;
#   color: #000000;
# }
# #T_78d02_row2_col0 {
#   background-color: #f3efec;
#   color: #000000;
# }
# #T_78d02_row3_col0 {
#   background-color: #f3f0ee;
#   color: #000000;
# }
# #T_78d02_row4_col0 {
#   background-color: #f4e6cf;
#   color: #000000;
# }
# </style>
# <table id="T_78d02" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78d02_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="index_name level1" >cld2__best_lang</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78d02_level0_row0" class="row_heading level0 row0" rowspan="5">kz-ru</th>
#       <th id="T_78d02_level1_row0" class="row_heading level1 row0" >kazakh</th>
#       <td id="T_78d02_row0_col0" class="data row0 col0" >0.479008</td>
#     </tr>
#     <tr>
#       <th id="T_78d02_level1_row1" class="row_heading level1 row1" >russian</th>
#       <td id="T_78d02_row1_col0" class="data row1 col0" >0.444656</td>
#     </tr>
#     <tr>
#       <th id="T_78d02_level1_row2" class="row_heading level1 row2" >serbian</th>
#       <td id="T_78d02_row2_col0" class="data row2 col0" >0.007634</td>
#     </tr>
#     <tr>
#       <th id="T_78d02_level1_row3" class="row_heading level1 row3" >tajik</th>
#       <td id="T_78d02_row3_col0" class="data row3 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_78d02_level1_row4" class="row_heading level1 row4" >un</th>
#       <td id="T_78d02_row4_col0" class="data row4 col0" >0.066794</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Для csw-текстов предсказывается в основном либо казахский, либо русский. В суммарно менее, чем 10% случаев предсказывается "неизвестный язык", сербский и таджикский.

# %% [markdown]
# #### Q3: Как хорошо метод предсказывает одноязычные тексты на нерелевантных языках?

# %%
# качество бинарной классификации для определения тега unk
sample = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz', 'ru', 'unk', 'skz'])]
y_true = (sample['manual_tag']=='unk').astype(int)
y_pred = (~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian'])).astype(int)

print(classification_report(y_true=y_true, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94      8739
#            1       0.04      0.95      0.08        43
#
#     accuracy                           0.89      8782
#    macro avg       0.52      0.92      0.51      8782
# weighted avg       1.00      0.89      0.94      8782

# %%
# какие языки предсказываются для unk
sample[(sample['manual_tag']=='unk')].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  cld2__best_lang
# unk         kazakh              2
#             kyrgyz              6
#             turkmen             1
#             ukrainian           7
#             un                 15
#             uzbek              12
# Name: text, dtype: int64

# %%
# для каких true тегов предсказывается "другой язык"
sample[(~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  cld2__best_lang
# kz          un                  13
# ru          bulgarian            5
#             english              1
#             kyrgyz               4
#             macedonian           1
#             mongolian            2
#             romanian             1
#             serbian             94
#             ukrainian            5
#             un                 701
# skz         kyrgyz              56
#             mongolian            1
#             serbian              1
#             tatar                1
#             turkmen              5
#             un                  29
#             uyghur               1
#             uzbek                4
# unk         kyrgyz               6
#             turkmen              1
#             ukrainian            7
#             un                  15
#             uzbek               12
# Name: text, dtype: int64

# %% [markdown]
# Из всех текстов на нерелевантных языках cld2 выявил 95%.
#
# При этом 96% текстов, определенных как "нерелевантные" на самом деле содержат казахский или русский.
#
# Что касается ошибочного определения языка, чаще всего казахский принимается за "неизвестный язык", русский -- за "неизвестный", сербский, болгарский, "упрощенное" написание казахского также принимается за киргизский и "неизвестный" язык.

# %% [markdown]
# #### Q4: Какие результаты для skz?

# %%
# какие языки определены для skz
y_pred = exprmnt.df[(exprmnt.df['manual_tag']=='skz')][f'{METHOD}__best_lang']

y_pred.value_counts() / len(y_pred)
# Out:
# cld2__best_lang
# kazakh       0.436782
# kyrgyz       0.321839
# un           0.166667
# turkmen      0.028736
# uzbek        0.022989
# serbian      0.005747
# mongolian    0.005747
# uyghur       0.005747
# tatar        0.005747
# Name: count, dtype: float64

# %% [markdown]
# Для текстов, помеченных тегом skz метод предсказывает казахский (44%), киргизский (32%),  "неизвестный язык" (17%) и другие: туркменский, узбекский, сербский, монгольский, уйгурский, татарский.

# %% [markdown]
# #### Q5: Что получим после фильтрации?

# %%
y_pred = exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']).astype(int)

# доля тегов, которые будут выкинуты
counts_ = (exprmnt.df[y_pred==0]['manual_tag'].value_counts() / exprmnt.df['manual_tag'].value_counts()).fillna(0).rename('will_be_excluded, %')

cm = sns.light_palette("green", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_ab2f8_row0_col0 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_ab2f8_row1_col0 {
#   background-color: #d8ead8;
#   color: #000000;
# }
# #T_ab2f8_row2_col0 {
#   background-color: #dcecdc;
#   color: #000000;
# }
# #T_ab2f8_row3_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_ab2f8_row4_col0 {
#   background-color: #c6e1c6;
#   color: #000000;
# }
# #T_ab2f8_row5_col0 {
#   background-color: #9ece9e;
#   color: #000000;
# }
# #T_ab2f8_row6_col0 {
#   background-color: #60af60;
#   color: #f1f1f1;
# }
# #T_ab2f8_row7_col0 {
#   background-color: #9acb9a;
#   color: #000000;
# }
# #T_ab2f8_row8_col0 {
#   background-color: #47a347;
#   color: #f1f1f1;
# }
# #T_ab2f8_row9_col0 {
#   background-color: #6fb76f;
#   color: #f1f1f1;
# }
# #T_ab2f8_row10_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ab2f8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab2f8_level0_col0" class="col_heading level0 col0" >will_be_excluded, %</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab2f8_level0_row0" class="row_heading level0 row0" >kz</th>
#       <td id="T_ab2f8_row0_col0" class="data row0 col0" >0.004117</td>
#     </tr>
#     <tr>
#       <th id="T_ab2f8_level0_row1" class="row_heading level0 row1" >kz-ru</th>
#       <td id="T_ab2f8_row1_col0" class="data row1 col0" >0.076336</td>
#     </tr>
#     <tr>
#       <th id="T_ab2f8_level0_row2" class="row_heading level0 row2" >kz-ru-unk</th>
#       <td id="T_ab2f8_row2_col0" class="data row2 col0" >0.062500</td>
#     </tr>
#     <tr>
#       <th id="T_ab2f8_level0_row3" class="row_heading level0 row3" >kz-unk</th>
#       <td id="T_ab2f8_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab2f8_level0_row4" class="row_heading level0 row4" >ru</th>
#       <td id="T_ab2f8_row4_col0" class="data row4 col0" >0.150546</td>
#     </tr>
#     <tr>
#       <th id="T_ab2f8_level0_row5" class="row_heading level0 row5" >ru-unk</th>
#       <td id="T_ab2f8_row5_col0" class="data row5 col0" >0.309859</td>
#     </tr>
#     <tr>
#       <th id="T_ab2f8_level0_row6" class="row_heading level0 row6" >skz</th>
#       <td id="T_ab2f8_row6_col0" class="data row6 col0" >0.563218</td>
#     </tr>
#     <tr>
#       <th id="T_ab2f8_level0_row7" class="row_heading level0 row7" >skz-ru</th>
#       <td id="T_ab2f8_row7_col0" class="data row7 col0" >0.327957</td>
#     </tr>
#     <tr>
#       <th id="T_ab2f8_level0_row8" class="row_heading level0 row8" >skz-ru-unk</th>
#       <td id="T_ab2f8_row8_col0" class="data row8 col0" >0.666667</td>
#     </tr>
#     <tr>
#       <th id="T_ab2f8_level0_row9" class="row_heading level0 row9" >skz-unk</th>
#       <td id="T_ab2f8_row9_col0" class="data row9 col0" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_ab2f8_level0_row10" class="row_heading level0 row10" >unk</th>
#       <td id="T_ab2f8_row10_col0" class="data row10 col0" >0.953488</td>
#     </tr>
#   </tbody>
# </table>

# %%
# абсолютные количества тегов, которые будут выкинуты
counts_ = exprmnt.df[y_pred==0]['manual_tag'].value_counts().rename('will_be_excluded')
counts_ = pd.concat([counts_,exprmnt.df['manual_tag'].value_counts().rename('total')], axis=1)
counts_.fillna(0)
# Out:
#             will_be_excluded  total
# manual_tag
# ru                     814.0   5407
# skz                     98.0    174
# skz-ru                  61.0    186
# unk                     41.0     43
# kz-ru                   40.0    524
# ru-unk                  22.0     71
# kz                      13.0   3158
# skz-ru-unk               2.0      3
# skz-unk                  2.0      4
# kz-ru-unk                1.0     16
# kz-unk                   0.0    113

# %% [markdown]
# Этот способ позволит избавиться от 95% нерелевантных текстов, затронув более 7% примеров с csw.

# %% [markdown]
# ## Compact Language Detector 3
#
# Репозиторий: https://github.com/google/cld3
#
# cld3 разработан для Chrome-браузера, на сегодняшний день существует как публичный архив.

# %% [markdown]
# ### Анализ

# %%
METHOD = 'cld3'

visualize_tags(exprmnt.df, method=METHOD, manual_col='manual_tag')

# %%
corrections = {'skz':'kz', 'skz-ru': 'kz-ru', 'skz-ru-unk': 'kz-ru-unk', 'skz-unk': 'kz-unk'}
exprmnt.df['manual_tag_adj'] = exprmnt.df['manual_tag'].replace(corrections)
exprmnt.df['manual_tag_adj'].value_counts()
# Out:
# manual_tag_adj
# ru           5407
# kz           3332
# kz-ru         710
# kz-unk        117
# ru-unk         71
# unk            43
# kz-ru-unk      19
# Name: count, dtype: int64

# %%
# direct csw prediction
y_true = exprmnt.df['manual_tag_adj'].str.contains('kz-ru')
y_pred = (exprmnt.df['cld3__kaz']>0.60) & (exprmnt.df['cld3__rus']>0.60)

print(classification_report(y_true=y_true, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.93      1.00      0.96      8970
#         True       0.61      0.03      0.05       729
#
#     accuracy                           0.93      9699
#    macro avg       0.77      0.51      0.51      9699
# weighted avg       0.90      0.93      0.89      9699

# %% [markdown]
# #### Q1: Для скольких одноязычных примеров (kz и ru) был правильно определен язык?

# %%
# какие теги предсказываются для текстов на казахском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))])
# Out:
# cld3__best_lang
# kazakh        0.990184
# kyrgyz        0.004433
# belarusian    0.001583
# russian       0.001267
# ukrainian     0.000633
# swedish       0.000633
# tajik         0.000317
# samoan        0.000317
# bulgarian     0.000317
# mongolian     0.000317
# Name: count, dtype: float64

# %%
# какие теги предсказываются для текстов на русском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))])
# Out:
# cld3__best_lang
# russian           0.945256
# bulgarian         0.013871
# ukrainian         0.010172
# belarusian        0.008877
# serbian           0.008323
# kyrgyz            0.005548
# macedonian        0.002034
# mongolian         0.001849
# kazakh            0.001665
# tajik             0.000740
# hi-latn           0.000370
# english           0.000370
# somali            0.000185
# portuguese        0.000185
# irish             0.000185
# southern sotho    0.000185
# french            0.000185
# Name: count, dtype: float64

# %% [markdown]
# Recall для казахского значительно выше, чем для русского -- 0.99 против 0.95

# %%
sample = exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz', 'ru'])) | (exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].copy()
sample['manual_tag'] = sample['manual_tag'].replace({'kz': 'kazakh', 'ru': 'russian'})

print(classification_report(y_true=sample['manual_tag'], y_pred=sample[f'{METHOD}__best_lang'], labels=['kazakh', 'russian']))
# Out:
#               precision    recall  f1-score   support
#
#       kazakh       0.89      0.99      0.94      3158
#      russian       0.92      0.95      0.93      5407
#
#    micro avg       0.91      0.96      0.93      8565
#    macro avg       0.90      0.97      0.93      8565
# weighted avg       0.91      0.96      0.93      8565

# %% [markdown]
# #### Q2: Что предсказывается для kz-ru?

# %%
counts_ = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz-ru'])].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
counts_ = (counts_ / exprmnt.df['manual_tag'].value_counts()).fillna(0)

cm = sns.light_palette("orange", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_f8a11_row0_col0 {
#   background-color: #f3efeb;
#   color: #000000;
# }
# #T_f8a11_row1_col0 {
#   background-color: #f3efec;
#   color: #000000;
# }
# #T_f8a11_row2_col0 {
#   background-color: #ffa809;
#   color: #000000;
# }
# #T_f8a11_row3_col0 {
#   background-color: #f3ede3;
#   color: #000000;
# }
# #T_f8a11_row4_col0, #T_f8a11_row5_col0, #T_f8a11_row8_col0 {
#   background-color: #f3f0ee;
#   color: #000000;
# }
# #T_f8a11_row6_col0 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_f8a11_row7_col0 {
#   background-color: #f3f0ed;
#   color: #000000;
# }
# #T_f8a11_row9_col0 {
#   background-color: #f3ede6;
#   color: #000000;
# }
# </style>
# <table id="T_f8a11" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8a11_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="index_name level1" >cld3__best_lang</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8a11_level0_row0" class="row_heading level0 row0" rowspan="10">kz-ru</th>
#       <th id="T_f8a11_level1_row0" class="row_heading level1 row0" >belarusian</th>
#       <td id="T_f8a11_row0_col0" class="data row0 col0" >0.009542</td>
#     </tr>
#     <tr>
#       <th id="T_f8a11_level1_row1" class="row_heading level1 row1" >bulgarian</th>
#       <td id="T_f8a11_row1_col0" class="data row1 col0" >0.007634</td>
#     </tr>
#     <tr>
#       <th id="T_f8a11_level1_row2" class="row_heading level1 row2" >kazakh</th>
#       <td id="T_f8a11_row2_col0" class="data row2 col0" >0.454198</td>
#     </tr>
#     <tr>
#       <th id="T_f8a11_level1_row3" class="row_heading level1 row3" >kyrgyz</th>
#       <td id="T_f8a11_row3_col0" class="data row3 col0" >0.024809</td>
#     </tr>
#     <tr>
#       <th id="T_f8a11_level1_row4" class="row_heading level1 row4" >macedonian</th>
#       <td id="T_f8a11_row4_col0" class="data row4 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_f8a11_level1_row5" class="row_heading level1 row5" >mongolian</th>
#       <td id="T_f8a11_row5_col0" class="data row5 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_f8a11_level1_row6" class="row_heading level1 row6" >russian</th>
#       <td id="T_f8a11_row6_col0" class="data row6 col0" >0.473282</td>
#     </tr>
#     <tr>
#       <th id="T_f8a11_level1_row7" class="row_heading level1 row7" >serbian</th>
#       <td id="T_f8a11_row7_col0" class="data row7 col0" >0.005725</td>
#     </tr>
#     <tr>
#       <th id="T_f8a11_level1_row8" class="row_heading level1 row8" >tajik</th>
#       <td id="T_f8a11_row8_col0" class="data row8 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_f8a11_level1_row9" class="row_heading level1 row9" >ukrainian</th>
#       <td id="T_f8a11_row9_col0" class="data row9 col0" >0.019084</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Для csw-текстов предсказывается в основном либо казахский, либо русский. В суммарно менее, чем 10% случаев предсказывается множество других языков: киргизский, украинский, белорусский, болгарский и др.

# %% [markdown]
# #### Q3: Как хорошо метод предсказывает одноязычные тексты на нерелевантных языках?

# %%
# качество бинарной классификации для определения тега unk
sample = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz', 'ru', 'unk', 'skz'])]
y_true = (sample['manual_tag']=='unk').astype(int)
y_pred = (~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian'])).astype(int)

print(classification_report(y_true=y_true, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      8739
#            1       0.08      0.91      0.14        43
#
#     accuracy                           0.95      8782
#    macro avg       0.54      0.93      0.56      8782
# weighted avg       1.00      0.95      0.97      8782

# %%
# какие языки предсказываются для unk
sample[(sample['manual_tag']=='unk')].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  cld3__best_lang
# unk         bulgarian           2
#             kazakh              2
#             kyrgyz             19
#             macedonian          1
#             mongolian           5
#             russian             2
#             serbian             1
#             tajik               3
#             ukrainian           8
# Name: text, dtype: int64

# %%
# для каких true тегов предсказывается "другой язык"
sample[(~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  cld3__best_lang
# kz          belarusian           5
#             bulgarian            1
#             kyrgyz              14
#             mongolian            1
#             samoan               1
#             swedish              2
#             tajik                1
#             ukrainian            2
# ru          belarusian          48
#             bulgarian           75
#             english              2
#             french               1
#             hi-latn              2
#             irish                1
#             kyrgyz              30
#             macedonian          11
#             mongolian           10
#             portuguese           1
#             serbian             45
#             somali               1
#             southern sotho       1
#             tajik                4
#             ukrainian           55
# skz         belarusian           3
#             bulgarian            1
#             kyrgyz             140
# unk         bulgarian            2
#             kyrgyz              19
#             macedonian           1
#             mongolian            5
#             serbian              1
#             tajik                3
#             ukrainian            8
# Name: text, dtype: int64

# %% [markdown]
# Из всех текстов на нерелевантных языках cld3 выявил 91%.
#
# При этом 92% текстов, определенных как "нерелевантные" на самом деле содержат казахский или русский.
#
# Что касается ошибочного определения языка, чаще всего казахский принимается за киргизский, русский -- за болгарский, украинский, белорусский, сербский и киргизский, "упрощенное" написание казахского также принимается за киргизский язык.

# %% [markdown]
# #### Q4: Какие результаты для skz?

# %%
# какие языки определены для skz
y_pred = exprmnt.df[(exprmnt.df['manual_tag']=='skz')][f'{METHOD}__best_lang']

y_pred.value_counts() / len(y_pred)
# Out:
# cld3__best_lang
# kyrgyz        0.804598
# kazakh        0.149425
# russian       0.022989
# belarusian    0.017241
# bulgarian     0.005747
# Name: count, dtype: float64

# %% [markdown]
# Для текстов, помеченных тегом skz в подавляющем большинстве случаев предсказывается киргизский -- 80%

# %% [markdown]
# #### Q5: Что получим после фильтрации?

# %%
y_pred = exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']).astype(int)

# доля тегов, которые будут выкинуты
counts_ = (exprmnt.df[y_pred==0]['manual_tag'].value_counts() / exprmnt.df['manual_tag'].value_counts()).fillna(0).rename('will_be_excluded, %')

cm = sns.light_palette("green", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_b532c_row0_col0 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_b532c_row1_col0 {
#   background-color: #d8ead8;
#   color: #000000;
# }
# #T_b532c_row2_col0 {
#   background-color: #dbebdb;
#   color: #000000;
# }
# #T_b532c_row3_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_b532c_row4_col0 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_b532c_row5_col0 {
#   background-color: #9bcc9b;
#   color: #000000;
# }
# #T_b532c_row6_col0 {
#   background-color: #148a14;
#   color: #f1f1f1;
# }
# #T_b532c_row7_col0 {
#   background-color: #93c893;
#   color: #000000;
# }
# #T_b532c_row8_col0 {
#   background-color: #94c994;
#   color: #000000;
# }
# #T_b532c_row9_col0 {
#   background-color: #289428;
#   color: #f1f1f1;
# }
# #T_b532c_row10_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b532c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b532c_level0_col0" class="col_heading level0 col0" >will_be_excluded, %</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b532c_level0_row0" class="row_heading level0 row0" >kz</th>
#       <td id="T_b532c_row0_col0" class="data row0 col0" >0.008550</td>
#     </tr>
#     <tr>
#       <th id="T_b532c_level0_row1" class="row_heading level0 row1" >kz-ru</th>
#       <td id="T_b532c_row1_col0" class="data row1 col0" >0.072519</td>
#     </tr>
#     <tr>
#       <th id="T_b532c_level0_row2" class="row_heading level0 row2" >kz-ru-unk</th>
#       <td id="T_b532c_row2_col0" class="data row2 col0" >0.062500</td>
#     </tr>
#     <tr>
#       <th id="T_b532c_level0_row3" class="row_heading level0 row3" >kz-unk</th>
#       <td id="T_b532c_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b532c_level0_row4" class="row_heading level0 row4" >ru</th>
#       <td id="T_b532c_row4_col0" class="data row4 col0" >0.053079</td>
#     </tr>
#     <tr>
#       <th id="T_b532c_level0_row5" class="row_heading level0 row5" >ru-unk</th>
#       <td id="T_b532c_row5_col0" class="data row5 col0" >0.309859</td>
#     </tr>
#     <tr>
#       <th id="T_b532c_level0_row6" class="row_heading level0 row6" >skz</th>
#       <td id="T_b532c_row6_col0" class="data row6 col0" >0.827586</td>
#     </tr>
#     <tr>
#       <th id="T_b532c_level0_row7" class="row_heading level0 row7" >skz-ru</th>
#       <td id="T_b532c_row7_col0" class="data row7 col0" >0.338710</td>
#     </tr>
#     <tr>
#       <th id="T_b532c_level0_row8" class="row_heading level0 row8" >skz-ru-unk</th>
#       <td id="T_b532c_row8_col0" class="data row8 col0" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_b532c_level0_row9" class="row_heading level0 row9" >skz-unk</th>
#       <td id="T_b532c_row9_col0" class="data row9 col0" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_b532c_level0_row10" class="row_heading level0 row10" >unk</th>
#       <td id="T_b532c_row10_col0" class="data row10 col0" >0.906977</td>
#     </tr>
#   </tbody>
# </table>

# %%
# абсолютные количества тегов, которые будут выкинуты
counts_ = exprmnt.df[y_pred==0]['manual_tag'].value_counts().rename('will_be_excluded')
counts_ = pd.concat([counts_,exprmnt.df['manual_tag'].value_counts().rename('total')], axis=1)
counts_.fillna(0)
# Out:
#             will_be_excluded  total
# manual_tag
# ru                     287.0   5407
# skz                    144.0    174
# skz-ru                  63.0    186
# unk                     39.0     43
# kz-ru                   38.0    524
# kz                      27.0   3158
# ru-unk                  22.0     71
# skz-unk                  3.0      4
# skz-ru-unk               1.0      3
# kz-ru-unk                1.0     16
# kz-unk                   0.0    113

# %% [markdown]
# Этот способ позволит избавиться от 91% нерелевантных текстов, затронув более 7% примеров с csw.

# %% [markdown]
# ## Fast-langdetect
#
# https://github.com/LlmKira/fast-langdetect
#
# Обертка, ускоряющая работу FastText

# %% [markdown]
# ### Анализ

# %%
METHOD = 'fast_langdetect'

visualize_tags(exprmnt.df, method=METHOD, manual_col='manual_tag')

# %% [markdown]
# #### Q1: Для скольких одноязычных примеров (kz и ru) был правильно определен язык?

# %%
# какие теги предсказываются для текстов на казахском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))])
# Out:
# fast_langdetect__best_lang
# kazakh        0.987017
# ukrainian     0.004117
# russian       0.003800
# kyrgyz        0.001583
# tatar         0.001267
# bulgarian     0.000633
# mongolian     0.000633
# bashkir       0.000633
# macedonian    0.000317
# Name: count, dtype: float64

# %%
# какие теги предсказываются для текстов на русском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))])
# Out:
# fast_langdetect__best_lang
# russian      0.996486
# kyrgyz       0.000925
# serbian      0.000740
# bulgarian    0.000740
# ukrainian    0.000370
# chechen      0.000370
# yakut        0.000185
# mongolian    0.000185
# Name: count, dtype: float64

# %% [markdown]
# Recall для казахского и для русского близок к "идеальному" -- 0.9870 и 0.9965

# %%
sample = exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz', 'ru'])) | (exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].copy()
sample['manual_tag'] = sample['manual_tag'].replace({'kz': 'kazakh', 'ru': 'russian'})

print(classification_report(y_true=sample['manual_tag'], y_pred=sample[f'{METHOD}__best_lang'], labels=['kazakh', 'russian']))
# Out:
#               precision    recall  f1-score   support
#
#       kazakh       0.89      0.99      0.94      3158
#      russian       0.90      1.00      0.95      5407
#
#    micro avg       0.90      0.99      0.94      8565
#    macro avg       0.90      0.99      0.94      8565
# weighted avg       0.90      0.99      0.94      8565

# %% [markdown]
# #### Q2: Что предсказывается для kz-ru?

# %%
counts_ = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz-ru'])].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
counts_ = (counts_ / exprmnt.df['manual_tag'].value_counts()).fillna(0)

cm = sns.light_palette("orange", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_2884e_row0_col0, #T_2884e_row1_col0, #T_2884e_row2_col0, #T_2884e_row5_col0, #T_2884e_row7_col0, #T_2884e_row8_col0 {
#   background-color: #f3f0ee;
#   color: #000000;
# }
# #T_2884e_row3_col0 {
#   background-color: #fdaf20;
#   color: #000000;
# }
# #T_2884e_row4_col0 {
#   background-color: #f3efea;
#   color: #000000;
# }
# #T_2884e_row6_col0 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_2884e_row9_col0 {
#   background-color: #f3eee7;
#   color: #000000;
# }
# </style>
# <table id="T_2884e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2884e_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="index_name level1" >fast_langdetect__best_lang</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2884e_level0_row0" class="row_heading level0 row0" rowspan="10">kz-ru</th>
#       <th id="T_2884e_level1_row0" class="row_heading level1 row0" >bashkir</th>
#       <td id="T_2884e_row0_col0" class="data row0 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_2884e_level1_row1" class="row_heading level1 row1" >belarusian</th>
#       <td id="T_2884e_row1_col0" class="data row1 col0" >0.003817</td>
#     </tr>
#     <tr>
#       <th id="T_2884e_level1_row2" class="row_heading level1 row2" >bulgarian</th>
#       <td id="T_2884e_row2_col0" class="data row2 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_2884e_level1_row3" class="row_heading level1 row3" >kazakh</th>
#       <td id="T_2884e_row3_col0" class="data row3 col0" >0.442748</td>
#     </tr>
#     <tr>
#       <th id="T_2884e_level1_row4" class="row_heading level1 row4" >kyrgyz</th>
#       <td id="T_2884e_row4_col0" class="data row4 col0" >0.013359</td>
#     </tr>
#     <tr>
#       <th id="T_2884e_level1_row5" class="row_heading level1 row5" >macedonian</th>
#       <td id="T_2884e_row5_col0" class="data row5 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_2884e_level1_row6" class="row_heading level1 row6" >russian</th>
#       <td id="T_2884e_row6_col0" class="data row6 col0" >0.511450</td>
#     </tr>
#     <tr>
#       <th id="T_2884e_level1_row7" class="row_heading level1 row7" >tajik</th>
#       <td id="T_2884e_row7_col0" class="data row7 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_2884e_level1_row8" class="row_heading level1 row8" >tatar</th>
#       <td id="T_2884e_row8_col0" class="data row8 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_2884e_level1_row9" class="row_heading level1 row9" >ukrainian</th>
#       <td id="T_2884e_row9_col0" class="data row9 col0" >0.019084</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Для csw-текстов предсказывается либо казахский, либо русский (44% и 51%), и только в 5% -- другие языки

# %% [markdown]
# #### Q3: Как хорошо метод предсказывает одноязычные тексты на нерелевантных языках?

# %%
# качество бинарной классификации для определения тега unk
sample = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz', 'ru', 'unk', 'skz'])]
y_true = (sample['manual_tag']=='unk').astype(int)
y_pred = (~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian'])).astype(int)

print(classification_report(y_true=y_true, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      8739
#            1       0.13      0.51      0.21        43
#
#     accuracy                           0.98      8782
#    macro avg       0.56      0.75      0.60      8782
# weighted avg       0.99      0.98      0.99      8782

# %%
# какие языки предсказываются для unk
sample[(sample['manual_tag']=='unk')].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  fast_langdetect__best_lang
# unk         bulgarian                      3
#             chuvash                        1
#             kazakh                         2
#             kyrgyz                         5
#             russian                       19
#             ukrainian                      8
#             yakut                          5
# Name: text, dtype: int64

# %%
# для каких true тегов предсказывается "другой язык"
sample[(~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  fast_langdetect__best_lang
# kz          bashkir                        2
#             bulgarian                      2
#             kyrgyz                         5
#             macedonian                     1
#             mongolian                      2
#             tatar                          4
#             ukrainian                     13
# ru          bulgarian                      4
#             chechen                        2
#             kyrgyz                         5
#             mongolian                      1
#             serbian                        4
#             ukrainian                      2
#             yakut                          1
# skz         bashkir                        1
#             belarusian                     1
#             karachay-balkar                1
#             kyrgyz                        82
#             macedonian                     1
#             mongolian                      4
#             tatar                          8
# unk         bulgarian                      3
#             chuvash                        1
#             kyrgyz                         5
#             ukrainian                      8
#             yakut                          5
# Name: text, dtype: int64

# %% [markdown]
# Из всех текстов на нерелевантных языках метод выявил всего 51%, и только 13% из них в действительности нерелевантные.
#
# Что касается ошибочного определения языка, чаще всего казахский принимается за украинский, "упрощенное" написание казахского принимается за киргизский язык.

# %% [markdown]
# #### Q4: Какие результаты для skz?

# %%
# какие языки определены для skz
y_pred = exprmnt.df[(exprmnt.df['manual_tag']=='skz')][f'{METHOD}__best_lang']

y_pred.value_counts() / len(y_pred)
# Out:
# fast_langdetect__best_lang
# kyrgyz             0.471264
# russian            0.304598
# kazakh             0.132184
# tatar              0.045977
# mongolian          0.022989
# karachay-balkar    0.005747
# belarusian         0.005747
# bashkir            0.005747
# macedonian         0.005747
# Name: count, dtype: float64

# %% [markdown]
# Для текстов, помеченных тегом skz в подавляющем большинстве случаев предсказывается киргизский -- 47%

# %% [markdown]
# #### Q5: Что получим после фильтрации?

# %%
y_pred = exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']).astype(int)

# доля тегов, которые будут выкинуты
counts_ = (exprmnt.df[y_pred==0]['manual_tag'].value_counts() / exprmnt.df['manual_tag'].value_counts()).fillna(0).rename('will_be_excluded, %')

cm = sns.light_palette("green", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_8cbb0_row0_col0, #T_8cbb0_row3_col0 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_8cbb0_row1_col0 {
#   background-color: #dcecdc;
#   color: #000000;
# }
# #T_8cbb0_row2_col0 {
#   background-color: #d6e9d6;
#   color: #000000;
# }
# #T_8cbb0_row4_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_8cbb0_row5_col0 {
#   background-color: #badbba;
#   color: #000000;
# }
# #T_8cbb0_row6_col0 {
#   background-color: #249224;
#   color: #f1f1f1;
# }
# #T_8cbb0_row7_col0 {
#   background-color: #c8e2c8;
#   color: #000000;
# }
# #T_8cbb0_row8_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_8cbb0_row9_col0 {
#   background-color: #93c893;
#   color: #000000;
# }
# #T_8cbb0_row10_col0 {
#   background-color: #369b36;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8cbb0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8cbb0_level0_col0" class="col_heading level0 col0" >will_be_excluded, %</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8cbb0_level0_row0" class="row_heading level0 row0" >kz</th>
#       <td id="T_8cbb0_row0_col0" class="data row0 col0" >0.009183</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb0_level0_row1" class="row_heading level0 row1" >kz-ru</th>
#       <td id="T_8cbb0_row1_col0" class="data row1 col0" >0.045802</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb0_level0_row2" class="row_heading level0 row2" >kz-ru-unk</th>
#       <td id="T_8cbb0_row2_col0" class="data row2 col0" >0.062500</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb0_level0_row3" class="row_heading level0 row3" >kz-unk</th>
#       <td id="T_8cbb0_row3_col0" class="data row3 col0" >0.008850</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb0_level0_row4" class="row_heading level0 row4" >ru</th>
#       <td id="T_8cbb0_row4_col0" class="data row4 col0" >0.003514</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb0_level0_row5" class="row_heading level0 row5" >ru-unk</th>
#       <td id="T_8cbb0_row5_col0" class="data row5 col0" >0.140845</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb0_level0_row6" class="row_heading level0 row6" >skz</th>
#       <td id="T_8cbb0_row6_col0" class="data row6 col0" >0.563218</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb0_level0_row7" class="row_heading level0 row7" >skz-ru</th>
#       <td id="T_8cbb0_row7_col0" class="data row7 col0" >0.102151</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb0_level0_row8" class="row_heading level0 row8" >skz-ru-unk</th>
#       <td id="T_8cbb0_row8_col0" class="data row8 col0" >0.666667</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb0_level0_row9" class="row_heading level0 row9" >skz-unk</th>
#       <td id="T_8cbb0_row9_col0" class="data row9 col0" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_8cbb0_level0_row10" class="row_heading level0 row10" >unk</th>
#       <td id="T_8cbb0_row10_col0" class="data row10 col0" >0.511628</td>
#     </tr>
#   </tbody>
# </table>

# %%
# абсолютные количества тегов, которые будут выкинуты
counts_ = exprmnt.df[y_pred==0]['manual_tag'].value_counts().rename('will_be_excluded')
counts_ = pd.concat([counts_,exprmnt.df['manual_tag'].value_counts().rename('total')], axis=1)
counts_.fillna(0)
# Out:
#             will_be_excluded  total
# manual_tag
# skz                       98    174
# kz                        29   3158
# kz-ru                     24    524
# unk                       22     43
# skz-ru                    19    186
# ru                        19   5407
# ru-unk                    10     71
# skz-ru-unk                 2      3
# kz-ru-unk                  1     16
# skz-unk                    1      4
# kz-unk                     1    113

# %% [markdown]
# Этот способ позволит избавиться от 51% нерелевантных текстов, затронув более 4.6% примеров с csw.

# %% [markdown]
# ## LangID
#
# https://github.com/saffsd/langid.py (новая версия: https://github.com/adbar/py3langid)

# %% [markdown]
# ### Анализ

# %%
METHOD = 'langid'

visualize_tags(exprmnt.df, method=METHOD, manual_col='manual_tag')

# %% [markdown]
# #### Q1: Для скольких одноязычных примеров (kz и ru) был правильно определен язык?

# %%
# какие теги предсказываются для текстов на казахском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))])
# Out:
# langid__best_lang
# kazakh        0.981317
# russian       0.014566
# macedonian    0.000950
# ukrainian     0.000950
# mongolian     0.000950
# belarusian    0.000633
# serbian       0.000633
# Name: count, dtype: float64

# %%
# какие теги предсказываются для текстов на русском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))])
# Out:
# langid__best_lang
# russian       0.917329
# bulgarian     0.033660
# ukrainian     0.017200
# serbian       0.012391
# macedonian    0.011282
# kazakh        0.004254
# belarusian    0.003329
# mongolian     0.000370
# kyrgyz        0.000185
# Name: count, dtype: float64

# %% [markdown]
# Recall для казахского значительно выше, чем для русского -- 0.98 против 0.92

# %%
sample = exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz', 'ru'])) | (exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].copy()
sample['manual_tag'] = sample['manual_tag'].replace({'kz': 'kazakh', 'ru': 'russian'})

print(classification_report(y_true=sample['manual_tag'], y_pred=sample[f'{METHOD}__best_lang'], labels=['kazakh', 'russian']))
# Out:
#               precision    recall  f1-score   support
#
#       kazakh       0.88      0.98      0.93      3158
#      russian       0.88      0.92      0.90      5407
#
#    micro avg       0.88      0.94      0.91      8565
#    macro avg       0.88      0.95      0.91      8565
# weighted avg       0.88      0.94      0.91      8565

# %% [markdown]
# #### Q2: Что предсказывается для kz-ru?

# %%
counts_ = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz-ru'])].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
counts_ = (counts_ / exprmnt.df['manual_tag'].value_counts()).fillna(0)

cm = sns.light_palette("orange", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_4481c_row0_col0 {
#   background-color: #f3eee8;
#   color: #000000;
# }
# #T_4481c_row1_col0 {
#   background-color: #fac462;
#   color: #000000;
# }
# #T_4481c_row2_col0, #T_4481c_row3_col0 {
#   background-color: #f3f0ee;
#   color: #000000;
# }
# #T_4481c_row4_col0 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_4481c_row5_col0 {
#   background-color: #f3f0ed;
#   color: #000000;
# }
# #T_4481c_row6_col0 {
#   background-color: #f3eee9;
#   color: #000000;
# }
# </style>
# <table id="T_4481c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4481c_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="index_name level1" >langid__best_lang</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4481c_level0_row0" class="row_heading level0 row0" rowspan="7">kz-ru</th>
#       <th id="T_4481c_level1_row0" class="row_heading level1 row0" >bulgarian</th>
#       <td id="T_4481c_row0_col0" class="data row0 col0" >0.019084</td>
#     </tr>
#     <tr>
#       <th id="T_4481c_level1_row1" class="row_heading level1 row1" >kazakh</th>
#       <td id="T_4481c_row1_col0" class="data row1 col0" >0.353053</td>
#     </tr>
#     <tr>
#       <th id="T_4481c_level1_row2" class="row_heading level1 row2" >macedonian</th>
#       <td id="T_4481c_row2_col0" class="data row2 col0" >0.003817</td>
#     </tr>
#     <tr>
#       <th id="T_4481c_level1_row3" class="row_heading level1 row3" >mongolian</th>
#       <td id="T_4481c_row3_col0" class="data row3 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_4481c_level1_row4" class="row_heading level1 row4" >russian</th>
#       <td id="T_4481c_row4_col0" class="data row4 col0" >0.599237</td>
#     </tr>
#     <tr>
#       <th id="T_4481c_level1_row5" class="row_heading level1 row5" >serbian</th>
#       <td id="T_4481c_row5_col0" class="data row5 col0" >0.005725</td>
#     </tr>
#     <tr>
#       <th id="T_4481c_level1_row6" class="row_heading level1 row6" >ukrainian</th>
#       <td id="T_4481c_row6_col0" class="data row6 col0" >0.017176</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Для csw-текстов предсказывается в основном либо казахский, либо русский? причем в отличие от других методов, langid в таких случаях значительно охотнее предсказывает русский язык (60%), чем казахский (35%).

# %% [markdown]
# #### Q3: Как хорошо метод предсказывает одноязычные тексты на нерелевантных языках?

# %%
# качество бинарной классификации для определения тега unk
sample = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz', 'ru', 'unk', 'skz'])]
y_true = (sample['manual_tag']=='unk').astype(int)
y_pred = (~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian'])).astype(int)

print(classification_report(y_true=y_true, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      8739
#            1       0.05      0.56      0.09        43
#
#     accuracy                           0.95      8782
#    macro avg       0.52      0.75      0.53      8782
# weighted avg       0.99      0.95      0.97      8782

# %%
# какие языки предсказываются для unk
sample[(sample['manual_tag']=='unk')].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  langid__best_lang
# unk         belarusian            2
#             bulgarian             2
#             kazakh                8
#             kyrgyz                1
#             mongolian             5
#             russian              11
#             serbian               2
#             ukrainian            12
# Name: text, dtype: int64

# %%
# для каких true тегов предсказывается "другой язык"
sample[(~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  langid__best_lang
# kz          belarusian             2
#             macedonian             3
#             mongolian              3
#             serbian                2
#             ukrainian              3
# ru          belarusian            18
#             bulgarian            182
#             kyrgyz                 1
#             macedonian            61
#             mongolian              2
#             serbian               67
#             ukrainian             93
# skz         belarusian             3
#             bulgarian              1
#             kyrgyz                12
#             macedonian             2
#             mongolian              2
#             serbian                3
#             ukrainian              2
# unk         belarusian             2
#             bulgarian              2
#             kyrgyz                 1
#             mongolian              5
#             serbian                2
#             ukrainian             12
# Name: text, dtype: int64

# %% [markdown]
# Из всех текстов на нерелевантных языках метод выявил всего 56%. При этом 95% текстов, определенных как "нерелевантные" на самом деле содержат казахский или русский.
#
# Что касается ошибочного определения языка, чаще всего казахский принимается за киргизский, русский -- за болгарский, украинский, македонский, сербский, "упрощенное" написание казахского также принимается за киргизский язык.

# %% [markdown]
# #### Q4: Какие результаты для skz?

# %%
# какие языки определены для skz
y_pred = exprmnt.df[(exprmnt.df['manual_tag']=='skz')][f'{METHOD}__best_lang']

y_pred.value_counts() / len(y_pred)
# Out:
# langid__best_lang
# kazakh        0.517241
# russian       0.339080
# kyrgyz        0.068966
# serbian       0.017241
# belarusian    0.017241
# macedonian    0.011494
# mongolian     0.011494
# ukrainian     0.011494
# bulgarian     0.005747
# Name: count, dtype: float64

# %% [markdown]
# Для текстов, помеченных тегом skz в половине случаев (52%) предсказывается казахский, в третьи случаев (34%) -- русский.

# %% [markdown]
# #### Q5: Что получим после фильтрации?

# %%
y_pred = exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']).astype(int)

# доля тегов, которые будут выкинуты
counts_ = (exprmnt.df[y_pred==0]['manual_tag'].value_counts() / exprmnt.df['manual_tag'].value_counts()).fillna(0).rename('will_be_excluded, %')

cm = sns.light_palette("green", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_1274e_row0_col0 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_1274e_row1_col0 {
#   background-color: #d7e9d7;
#   color: #000000;
# }
# #T_1274e_row2_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_1274e_row3_col0 {
#   background-color: #e7f1e7;
#   color: #000000;
# }
# #T_1274e_row4_col0 {
#   background-color: #cae3ca;
#   color: #000000;
# }
# #T_1274e_row5_col0 {
#   background-color: #a4d0a4;
#   color: #000000;
# }
# #T_1274e_row6_col0 {
#   background-color: #afd6af;
#   color: #000000;
# }
# #T_1274e_row7_col0 {
#   background-color: #d0e6d0;
#   color: #000000;
# }
# #T_1274e_row8_col0 {
#   background-color: #5fae5f;
#   color: #f1f1f1;
# }
# #T_1274e_row9_col0 {
#   background-color: #82c082;
#   color: #000000;
# }
# #T_1274e_row10_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1274e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1274e_level0_col0" class="col_heading level0 col0" >will_be_excluded, %</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1274e_level0_row0" class="row_heading level0 row0" >kz</th>
#       <td id="T_1274e_row0_col0" class="data row0 col0" >0.004117</td>
#     </tr>
#     <tr>
#       <th id="T_1274e_level0_row1" class="row_heading level0 row1" >kz-ru</th>
#       <td id="T_1274e_row1_col0" class="data row1 col0" >0.047710</td>
#     </tr>
#     <tr>
#       <th id="T_1274e_level0_row2" class="row_heading level0 row2" >kz-ru-unk</th>
#       <td id="T_1274e_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1274e_level0_row3" class="row_heading level0 row3" >kz-unk</th>
#       <td id="T_1274e_row3_col0" class="data row3 col0" >0.008850</td>
#     </tr>
#     <tr>
#       <th id="T_1274e_level0_row4" class="row_heading level0 row4" >ru</th>
#       <td id="T_1274e_row4_col0" class="data row4 col0" >0.078417</td>
#     </tr>
#     <tr>
#       <th id="T_1274e_level0_row5" class="row_heading level0 row5" >ru-unk</th>
#       <td id="T_1274e_row5_col0" class="data row5 col0" >0.169014</td>
#     </tr>
#     <tr>
#       <th id="T_1274e_level0_row6" class="row_heading level0 row6" >skz</th>
#       <td id="T_1274e_row6_col0" class="data row6 col0" >0.143678</td>
#     </tr>
#     <tr>
#       <th id="T_1274e_level0_row7" class="row_heading level0 row7" >skz-ru</th>
#       <td id="T_1274e_row7_col0" class="data row7 col0" >0.064516</td>
#     </tr>
#     <tr>
#       <th id="T_1274e_level0_row8" class="row_heading level0 row8" >skz-ru-unk</th>
#       <td id="T_1274e_row8_col0" class="data row8 col0" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_1274e_level0_row9" class="row_heading level0 row9" >skz-unk</th>
#       <td id="T_1274e_row9_col0" class="data row9 col0" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_1274e_level0_row10" class="row_heading level0 row10" >unk</th>
#       <td id="T_1274e_row10_col0" class="data row10 col0" >0.558140</td>
#     </tr>
#   </tbody>
# </table>

# %%
# абсолютные количества тегов, которые будут выкинуты
counts_ = exprmnt.df[y_pred==0]['manual_tag'].value_counts().rename('will_be_excluded')
counts_ = pd.concat([counts_,exprmnt.df['manual_tag'].value_counts().rename('total')], axis=1)
counts_.fillna(0)
# Out:
#             will_be_excluded  total
# manual_tag
# ru                     424.0   5407
# skz                     25.0    174
# kz-ru                   25.0    524
# unk                     24.0     43
# kz                      13.0   3158
# skz-ru                  12.0    186
# ru-unk                  12.0     71
# skz-unk                  1.0      4
# kz-unk                   1.0    113
# skz-ru-unk               1.0      3
# kz-ru-unk                0.0     16

# %% [markdown]
# Этот способ позволит избавиться от 56% нерелевантных текстов, затронув около 5% примеров с csw.

# %% [markdown]
# ## Lingua
# https://pypi.org/project/lingua-language-detector/

# %% [markdown]
# ### Анализ

# %%
METHOD = 'lingua'

visualize_tags(exprmnt.df, method=METHOD, manual_col='manual_tag')

# %%
corrections = {'skz':'kz', 'skz-ru': 'kz-ru', 'skz-ru-unk': 'kz-ru-unk', 'skz-unk': 'kz-unk'}
exprmnt.df['manual_tag_adj'] = exprmnt.df['manual_tag'].replace(corrections)
exprmnt.df['manual_tag_adj'].value_counts()
# Out:
# manual_tag_adj
# ru           5407
# kz           3332
# kz-ru         710
# kz-unk        117
# ru-unk         71
# unk            43
# kz-ru-unk      19
# Name: count, dtype: int64

# %%
# direct csw prediction
y_true = exprmnt.df['manual_tag_adj'].str.contains('kz-ru')
y_pred = exprmnt.df['lingua__all_langs'].str.contains('kz-ru')

print(classification_report(y_true=y_true, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.95      0.97      0.96      8970
#         True       0.48      0.39      0.43       729
#
#     accuracy                           0.92      9699
#    macro avg       0.71      0.68      0.69      9699
# weighted avg       0.92      0.92      0.92      9699

# %%
# какие предсказания дает lingua для csw-текстов
df[(y_true==1)]['lingua__all_langs'].value_counts()
# Out:
# lingua__all_langs
# kz-ru        154
# kz           150
# kz-ru-unk    127
# ru-unk       121
# ru            99
# kz-unk        42
# unk           36
# Name: count, dtype: int64

# %% [markdown]
# #### Q1: Для скольких одноязычных примеров (kz и ru) был правильно определен язык?

# %%
# какие теги предсказываются для текстов на казахском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))])
# Out:
# lingua__best_lang
# kazakh        0.999050
# somali        0.000317
# macedonian    0.000317
# belarusian    0.000317
# Name: count, dtype: float64

# %%
# какие теги предсказываются для текстов на русском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))])
# Out:
# lingua__best_lang
# russian       0.985944
# bulgarian     0.003514
# mongolian     0.002774
# ukrainian     0.002589
# macedonian    0.001849
# kazakh        0.001665
# serbian       0.000925
# belarusian    0.000740
# Name: count, dtype: float64

# %%
sample = exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz', 'ru'])) | (exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].copy()
sample['manual_tag'] = sample['manual_tag'].replace({'kz': 'kazakh', 'ru': 'russian'})

print(classification_report(y_true=sample['manual_tag'], y_pred=sample[f'{METHOD}__best_lang'], labels=['kazakh', 'russian']))
# Out:
#               precision    recall  f1-score   support
#
#       kazakh       0.84      1.00      0.91      3158
#      russian       0.92      0.99      0.95      5407
#
#    micro avg       0.89      0.99      0.94      8565
#    macro avg       0.88      0.99      0.93      8565
# weighted avg       0.89      0.99      0.94      8565

# %% [markdown]
# Recall для казахского значительно почти идеальный -- 0.9990 и 0.9859

# %% [markdown]
# #### Q2: Что предсказывается для kz-ru?

# %%
counts_ = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz-ru'])].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
counts_ = (counts_ / exprmnt.df['manual_tag'].value_counts()).fillna(0)

cm = sns.light_palette("orange", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_fd3d5_row0_col0, #T_fd3d5_row1_col0 {
#   background-color: #f3f0ed;
#   color: #000000;
# }
# #T_fd3d5_row2_col0 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_fd3d5_row3_col0, #T_fd3d5_row4_col0, #T_fd3d5_row6_col0 {
#   background-color: #f3f0ee;
#   color: #000000;
# }
# #T_fd3d5_row5_col0 {
#   background-color: #fdaf20;
#   color: #000000;
# }
# #T_fd3d5_row7_col0 {
#   background-color: #f3eee8;
#   color: #000000;
# }
# </style>
# <table id="T_fd3d5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd3d5_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="index_name level1" >lingua__best_lang</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd3d5_level0_row0" class="row_heading level0 row0" rowspan="8">kz-ru</th>
#       <th id="T_fd3d5_level1_row0" class="row_heading level1 row0" >belarusian</th>
#       <td id="T_fd3d5_row0_col0" class="data row0 col0" >0.005725</td>
#     </tr>
#     <tr>
#       <th id="T_fd3d5_level1_row1" class="row_heading level1 row1" >bulgarian</th>
#       <td id="T_fd3d5_row1_col0" class="data row1 col0" >0.007634</td>
#     </tr>
#     <tr>
#       <th id="T_fd3d5_level1_row2" class="row_heading level1 row2" >kazakh</th>
#       <td id="T_fd3d5_row2_col0" class="data row2 col0" >0.515267</td>
#     </tr>
#     <tr>
#       <th id="T_fd3d5_level1_row3" class="row_heading level1 row3" >macedonian</th>
#       <td id="T_fd3d5_row3_col0" class="data row3 col0" >0.003817</td>
#     </tr>
#     <tr>
#       <th id="T_fd3d5_level1_row4" class="row_heading level1 row4" >mongolian</th>
#       <td id="T_fd3d5_row4_col0" class="data row4 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_fd3d5_level1_row5" class="row_heading level1 row5" >russian</th>
#       <td id="T_fd3d5_row5_col0" class="data row5 col0" >0.446565</td>
#     </tr>
#     <tr>
#       <th id="T_fd3d5_level1_row6" class="row_heading level1 row6" >serbian</th>
#       <td id="T_fd3d5_row6_col0" class="data row6 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_fd3d5_level1_row7" class="row_heading level1 row7" >ukrainian</th>
#       <td id="T_fd3d5_row7_col0" class="data row7 col0" >0.017176</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Для csw-текстов предсказывается в основном либо казахский, либо русский -- 52% и 45%.

# %% [markdown]
# #### Q3: Как хорошо метод предсказывает одноязычные тексты на нерелевантных языках?

# %%
# качество бинарной классификации для определения тега unk
sample = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz', 'ru', 'unk', 'skz'])]
y_true = (sample['manual_tag']=='unk').astype(int)
y_pred = (~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian'])).astype(int)

print(classification_report(y_true=y_true, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      8739
#            1       0.24      0.58      0.34        43
#
#     accuracy                           0.99      8782
#    macro avg       0.62      0.79      0.66      8782
# weighted avg       0.99      0.99      0.99      8782

# %%
# какие языки предсказываются для unk
sample[(sample['manual_tag']=='unk')].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  lingua__best_lang
# unk         belarusian            2
#             bulgarian             1
#             english               1
#             kazakh                6
#             mongolian            10
#             russian              12
#             serbian               1
#             ukrainian            10
# Name: text, dtype: int64

# %%
# для каких true тегов предсказывается "другой язык"
sample[(~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  lingua__best_lang
# kz          belarusian            1
#             macedonian            1
#             somali                1
# ru          belarusian            4
#             bulgarian            19
#             macedonian           10
#             mongolian            15
#             serbian               5
#             ukrainian            14
# skz         bulgarian             1
#             mongolian             9
#             serbian               1
# unk         belarusian            2
#             bulgarian             1
#             english               1
#             mongolian            10
#             serbian               1
#             ukrainian            10
# Name: text, dtype: int64

# %% [markdown]
# Из всех текстов на нерелевантных языках метод выявил всего 58%. 76% текстов, определенных как "нерелевантные" на самом деле содержат казахский или русский.
#
# Что касается ошибочного определения языка, чаще всего русский определяется как болгарский, монгольский и украинский, "упрощенное" написание казахского также принимается за монгольский язык.

# %% [markdown]
# #### Q4: Какие результаты для skz?

# %%
# какие языки определены для skz
y_pred = exprmnt.df[(exprmnt.df['manual_tag']=='skz')][f'{METHOD}__best_lang']

y_pred.value_counts() / len(y_pred)
# Out:
# lingua__best_lang
# kazakh       0.890805
# mongolian    0.051724
# russian      0.045977
# bulgarian    0.005747
# serbian      0.005747
# Name: count, dtype: float64

# %% [markdown]
# Для текстов, помеченных тегом skz в подавляющем большинстве случаев (89%) предсказывается казахский.

# %% [markdown]
# #### Q5: Что получим после фильтрации?

# %%
y_pred = exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']).astype(int)

# доля тегов, которые будут выкинуты
counts_ = (exprmnt.df[y_pred==0]['manual_tag'].value_counts() / exprmnt.df['manual_tag'].value_counts()).fillna(0).rename('will_be_excluded, %')

cm = sns.light_palette("green", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_80a7d_row0_col0, #T_80a7d_row3_col0, #T_80a7d_row8_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_80a7d_row1_col0 {
#   background-color: #dcecdc;
#   color: #000000;
# }
# #T_80a7d_row2_col0 {
#   background-color: #b8dab8;
#   color: #000000;
# }
# #T_80a7d_row4_col0 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_80a7d_row5_col0 {
#   background-color: #b2d7b1;
#   color: #000000;
# }
# #T_80a7d_row6_col0 {
#   background-color: #d2e7d2;
#   color: #000000;
# }
# #T_80a7d_row7_col0 {
#   background-color: #daebda;
#   color: #000000;
# }
# #T_80a7d_row9_col0 {
#   background-color: #85c185;
#   color: #000000;
# }
# #T_80a7d_row10_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_80a7d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80a7d_level0_col0" class="col_heading level0 col0" >will_be_excluded, %</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80a7d_level0_row0" class="row_heading level0 row0" >kz</th>
#       <td id="T_80a7d_row0_col0" class="data row0 col0" >0.000950</td>
#     </tr>
#     <tr>
#       <th id="T_80a7d_level0_row1" class="row_heading level0 row1" >kz-ru</th>
#       <td id="T_80a7d_row1_col0" class="data row1 col0" >0.038168</td>
#     </tr>
#     <tr>
#       <th id="T_80a7d_level0_row2" class="row_heading level0 row2" >kz-ru-unk</th>
#       <td id="T_80a7d_row2_col0" class="data row2 col0" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_80a7d_level0_row3" class="row_heading level0 row3" >kz-unk</th>
#       <td id="T_80a7d_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80a7d_level0_row4" class="row_heading level0 row4" >ru</th>
#       <td id="T_80a7d_row4_col0" class="data row4 col0" >0.012391</td>
#     </tr>
#     <tr>
#       <th id="T_80a7d_level0_row5" class="row_heading level0 row5" >ru-unk</th>
#       <td id="T_80a7d_row5_col0" class="data row5 col0" >0.140845</td>
#     </tr>
#     <tr>
#       <th id="T_80a7d_level0_row6" class="row_heading level0 row6" >skz</th>
#       <td id="T_80a7d_row6_col0" class="data row6 col0" >0.063218</td>
#     </tr>
#     <tr>
#       <th id="T_80a7d_level0_row7" class="row_heading level0 row7" >skz-ru</th>
#       <td id="T_80a7d_row7_col0" class="data row7 col0" >0.043011</td>
#     </tr>
#     <tr>
#       <th id="T_80a7d_level0_row8" class="row_heading level0 row8" >skz-ru-unk</th>
#       <td id="T_80a7d_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_80a7d_level0_row9" class="row_heading level0 row9" >skz-unk</th>
#       <td id="T_80a7d_row9_col0" class="data row9 col0" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_80a7d_level0_row10" class="row_heading level0 row10" >unk</th>
#       <td id="T_80a7d_row10_col0" class="data row10 col0" >0.581395</td>
#     </tr>
#   </tbody>
# </table>

# %%
# абсолютные количества тегов, которые будут выкинуты
counts_ = exprmnt.df[y_pred==0]['manual_tag'].value_counts().rename('will_be_excluded')
counts_ = pd.concat([counts_,exprmnt.df['manual_tag'].value_counts().rename('total')], axis=1)
counts_.fillna(0)
# Out:
#             will_be_excluded  total
# manual_tag
# ru                      67.0   5407
# unk                     25.0     43
# kz-ru                   20.0    524
# skz                     11.0    174
# ru-unk                  10.0     71
# skz-ru                   8.0    186
# kz                       3.0   3158
# kz-ru-unk                2.0     16
# skz-unk                  1.0      4
# kz-unk                   0.0    113
# skz-ru-unk               0.0      3

# %% [markdown]
# Этот способ позволит избавиться от 58% нерелевантных текстов, затронув около 4% примеров с csw.

# %% [markdown]
# ## MediaPipe (Language deteciton)
#
# https://ai.google.dev/edge/mediapipe/solutions/text/language_detector
#
#
# архитектура: https://storage.googleapis.com/mediapipe-assets/LanguageDetector%20Model%20Card.pdf

# %% [markdown]
# ### Анализ

# %%
METHOD = 'mediapipe'

visualize_tags(exprmnt.df, method=METHOD, manual_col='manual_tag')

# %% [markdown]
# #### Q1: Для скольких одноязычных примеров (kz и ru) был правильно определен язык?

# %%
# какие теги предсказываются для текстов на казахском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))])
# Out:
# mediapipe__best_lang
# kazakh       0.990500
# kyrgyz       0.006016
# unknown      0.002217
# bulgarian    0.000633
# ukrainian    0.000317
# tajik        0.000317
# Name: count, dtype: float64

# %%
# какие теги предсказываются для текстов на русском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))])
# Out:
# mediapipe__best_lang
# russian       0.981136
# bulgarian     0.009802
# kyrgyz        0.003329
# ukrainian     0.001849
# serbian       0.001480
# unknown       0.001110
# mongolian     0.000740
# macedonian    0.000555
# Name: count, dtype: float64

# %% [markdown]
# Recall для казахского значительно почти идеальный -- 0.9905 и 0.9811

# %%
sample = exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz', 'ru'])) | (exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].copy()
sample['manual_tag'] = sample['manual_tag'].replace({'kz': 'kazakh', 'ru': 'russian'})

print(classification_report(y_true=sample['manual_tag'], y_pred=sample[f'{METHOD}__best_lang'], labels=['kazakh', 'russian']))
# Out:
#               precision    recall  f1-score   support
#
#       kazakh       0.89      0.99      0.94      3158
#      russian       0.92      0.98      0.95      5407
#
#    micro avg       0.91      0.98      0.95      8565
#    macro avg       0.91      0.99      0.94      8565
# weighted avg       0.91      0.98      0.95      8565

# %%
# точность
accuracy_score(y_true=sample['manual_tag'], y_pred=sample[f'{METHOD}__best_lang'])

# %% [markdown]
# #### Q2: Что предсказывается для kz-ru?

# %%
counts_ = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz-ru'])].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
counts_ = (counts_ / exprmnt.df['manual_tag'].value_counts()).fillna(0)

cm = sns.light_palette("orange", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_5000f_row0_col0 {
#   background-color: #f3f0ee;
#   color: #000000;
# }
# #T_5000f_row1_col0, #T_5000f_row6_col0, #T_5000f_row7_col0 {
#   background-color: #f3efec;
#   color: #000000;
# }
# #T_5000f_row2_col0 {
#   background-color: #ffa706;
#   color: #000000;
# }
# #T_5000f_row3_col0 {
#   background-color: #f3eee7;
#   color: #000000;
# }
# #T_5000f_row4_col0 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_5000f_row5_col0 {
#   background-color: #f3f0ed;
#   color: #000000;
# }
# </style>
# <table id="T_5000f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5000f_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="index_name level1" >mediapipe__best_lang</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5000f_level0_row0" class="row_heading level0 row0" rowspan="8">kz-ru</th>
#       <th id="T_5000f_level1_row0" class="row_heading level1 row0" >belarusian</th>
#       <td id="T_5000f_row0_col0" class="data row0 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_5000f_level1_row1" class="row_heading level1 row1" >bulgarian</th>
#       <td id="T_5000f_row1_col0" class="data row1 col0" >0.007634</td>
#     </tr>
#     <tr>
#       <th id="T_5000f_level1_row2" class="row_heading level1 row2" >kazakh</th>
#       <td id="T_5000f_row2_col0" class="data row2 col0" >0.471374</td>
#     </tr>
#     <tr>
#       <th id="T_5000f_level1_row3" class="row_heading level1 row3" >kyrgyz</th>
#       <td id="T_5000f_row3_col0" class="data row3 col0" >0.017176</td>
#     </tr>
#     <tr>
#       <th id="T_5000f_level1_row4" class="row_heading level1 row4" >russian</th>
#       <td id="T_5000f_row4_col0" class="data row4 col0" >0.482824</td>
#     </tr>
#     <tr>
#       <th id="T_5000f_level1_row5" class="row_heading level1 row5" >tajik</th>
#       <td id="T_5000f_row5_col0" class="data row5 col0" >0.003817</td>
#     </tr>
#     <tr>
#       <th id="T_5000f_level1_row6" class="row_heading level1 row6" >ukrainian</th>
#       <td id="T_5000f_row6_col0" class="data row6 col0" >0.007634</td>
#     </tr>
#     <tr>
#       <th id="T_5000f_level1_row7" class="row_heading level1 row7" >unknown</th>
#       <td id="T_5000f_row7_col0" class="data row7 col0" >0.007634</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Для csw-текстов предсказывается в основном либо казахский, либо русский -- 47% и 48%.

# %% [markdown]
# #### Q3: Как хорошо метод предсказывает одноязычные тексты на нерелевантных языках?

# %%
# качество бинарной классификации для определения тега unk
sample = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz', 'ru', 'unk', 'skz'])]
y_true = (sample['manual_tag']=='unk').astype(int)
y_pred = (~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian'])).astype(int)

print(classification_report(y_true=y_true, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      8739
#            1       0.12      0.95      0.22        43
#
#     accuracy                           0.97      8782
#    macro avg       0.56      0.96      0.60      8782
# weighted avg       1.00      0.97      0.98      8782

# %%
# какие языки предсказываются для unk
sample[(sample['manual_tag']=='unk')].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  mediapipe__best_lang
# unk         bulgarian                1
#             kazakh                   2
#             kyrgyz                  23
#             mongolian                2
#             tajik                    3
#             ukrainian                9
#             unknown                  3
# Name: text, dtype: int64

# %%
# для каких true тегов предсказывается "другой язык"
sample[(~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  mediapipe__best_lang
# kz          bulgarian                 2
#             kyrgyz                   19
#             tajik                     1
#             ukrainian                 1
#             unknown                   7
# ru          bulgarian                53
#             kyrgyz                   18
#             macedonian                3
#             mongolian                 4
#             serbian                   8
#             ukrainian                10
#             unknown                   6
# skz         bulgarian                 1
#             kyrgyz                  149
#             tajik                     1
#             unknown                   4
# unk         bulgarian                 1
#             kyrgyz                   23
#             mongolian                 2
#             tajik                     3
#             ukrainian                 9
#             unknown                   3
# Name: text, dtype: int64

# %% [markdown]
# Из всех текстов на нерелевантных языках метод выявил всего 92%. 12% из всех текстов, определенных как "нерелевантные" на самом деле содержат казахский или русский.
#
# Что касается ошибочного определения языка, чаще всего русский определяется как болгарский, киргизский и украинский, "упрощенное" написание казахского принимается за киргизский язык.

# %% [markdown]
# #### Q4: Какие результаты для skz?

# %%
# какие языки определены для skz
y_pred = exprmnt.df[(exprmnt.df['manual_tag']=='skz')][f'{METHOD}__best_lang']

y_pred.value_counts() / len(y_pred)
# Out:
# mediapipe__best_lang
# kyrgyz       0.856322
# kazakh       0.080460
# russian      0.028736
# unknown      0.022989
# bulgarian    0.005747
# tajik        0.005747
# Name: count, dtype: float64

# %% [markdown]
# Для текстов, помеченных тегом skz в подавляющем большинстве случаев (86%) предсказывается киргизский.

# %% [markdown]
# #### Q5: Что получим после фильтрации?

# %%
y_pred = exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']).astype(int)

# доля тегов, которые будут выкинуты
counts_ = (exprmnt.df[y_pred==0]['manual_tag'].value_counts() / exprmnt.df['manual_tag'].value_counts()).fillna(0).rename('will_be_excluded, %')

cm = sns.light_palette("green", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_f9884_row0_col0, #T_f9884_row3_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_f9884_row1_col0 {
#   background-color: #e1eee1;
#   color: #000000;
# }
# #T_f9884_row2_col0 {
#   background-color: #cee5ce;
#   color: #000000;
# }
# #T_f9884_row4_col0 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_f9884_row5_col0 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_f9884_row6_col0 {
#   background-color: #0f870f;
#   color: #f1f1f1;
# }
# #T_f9884_row7_col0, #T_f9884_row8_col0 {
#   background-color: #9bcc9b;
#   color: #000000;
# }
# #T_f9884_row9_col0 {
#   background-color: #339933;
#   color: #f1f1f1;
# }
# #T_f9884_row10_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f9884" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9884_level0_col0" class="col_heading level0 col0" >will_be_excluded, %</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9884_level0_row0" class="row_heading level0 row0" >kz</th>
#       <td id="T_f9884_row0_col0" class="data row0 col0" >0.009500</td>
#     </tr>
#     <tr>
#       <th id="T_f9884_level0_row1" class="row_heading level0 row1" >kz-ru</th>
#       <td id="T_f9884_row1_col0" class="data row1 col0" >0.045802</td>
#     </tr>
#     <tr>
#       <th id="T_f9884_level0_row2" class="row_heading level0 row2" >kz-ru-unk</th>
#       <td id="T_f9884_row2_col0" class="data row2 col0" >0.125000</td>
#     </tr>
#     <tr>
#       <th id="T_f9884_level0_row3" class="row_heading level0 row3" >kz-unk</th>
#       <td id="T_f9884_row3_col0" class="data row3 col0" >0.008850</td>
#     </tr>
#     <tr>
#       <th id="T_f9884_level0_row4" class="row_heading level0 row4" >ru</th>
#       <td id="T_f9884_row4_col0" class="data row4 col0" >0.018864</td>
#     </tr>
#     <tr>
#       <th id="T_f9884_level0_row5" class="row_heading level0 row5" >ru-unk</th>
#       <td id="T_f9884_row5_col0" class="data row5 col0" >0.211268</td>
#     </tr>
#     <tr>
#       <th id="T_f9884_level0_row6" class="row_heading level0 row6" >skz</th>
#       <td id="T_f9884_row6_col0" class="data row6 col0" >0.890805</td>
#     </tr>
#     <tr>
#       <th id="T_f9884_level0_row7" class="row_heading level0 row7" >skz-ru</th>
#       <td id="T_f9884_row7_col0" class="data row7 col0" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_f9884_level0_row8" class="row_heading level0 row8" >skz-ru-unk</th>
#       <td id="T_f9884_row8_col0" class="data row8 col0" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_f9884_level0_row9" class="row_heading level0 row9" >skz-unk</th>
#       <td id="T_f9884_row9_col0" class="data row9 col0" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_f9884_level0_row10" class="row_heading level0 row10" >unk</th>
#       <td id="T_f9884_row10_col0" class="data row10 col0" >0.953488</td>
#     </tr>
#   </tbody>
# </table>

# %%
# абсолютные количества тегов, которые будут выкинуты
counts_ = exprmnt.df[y_pred==0]['manual_tag'].value_counts().rename('will_be_excluded')
counts_ = pd.concat([counts_,exprmnt.df['manual_tag'].value_counts().rename('total')], axis=1)
counts_.fillna(0)
# Out:
#             will_be_excluded  total
# manual_tag
# skz                      155    174
# ru                       102   5407
# skz-ru                    62    186
# unk                       41     43
# kz                        30   3158
# kz-ru                     24    524
# ru-unk                    15     71
# skz-unk                    3      4
# kz-ru-unk                  2     16
# kz-unk                     1    113
# skz-ru-unk                 1      3

# %% [markdown]
# Этот способ позволит избавиться от 95% нерелевантных текстов, затронув около 5% примеров с csw.

# %% [markdown]
# ## GlotLID

# %% [markdown]
# ### Анализ

# %%
METHOD = 'glotlid'

visualize_tags(exprmnt.df, method=METHOD, manual_col='manual_tag')

# %% [markdown]
# #### Q1: Для скольких одноязычных примеров (kz и ru) был правильно определен язык?

# %%
# какие теги предсказываются для текстов на казахском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))])
# Out:
# glotlid__best_lang
# kazakh            0.994934
# bashkir           0.001267
# kyrgyz            0.000633
# halh mongolian    0.000633
# kara-kalpak       0.000317
# tatar             0.000317
# tajik             0.000317
# khakas            0.000317
# kalmyk            0.000317
# mbf_latn          0.000317
# belarusian        0.000317
# vlax romani       0.000317
# Name: count, dtype: float64

# %%
# какие теги предсказываются для текстов на русском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))])
# Out:
# glotlid__best_lang
# russian            0.990753
# old russian        0.003699
# bulgarian          0.001480
# khakas             0.000925
# yakut              0.000740
# ukrainian          0.000555
# serbian            0.000370
# und                0.000370
# karachay-balkar    0.000185
# eastern mari       0.000185
# southern altai     0.000185
# nogai              0.000185
# kyrgyz             0.000185
# anp_deva           0.000185
# Name: count, dtype: float64

# %% [markdown]
# Recall для казахского значительно почти идеальный -- 0.9949 и 0.9907

# %%
sample = exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz', 'ru'])) | (exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].copy()
sample['manual_tag'] = sample['manual_tag'].replace({'kz': 'kazakh', 'ru': 'russian'})

print(classification_report(y_true=sample['manual_tag'], y_pred=sample[f'{METHOD}__best_lang'], labels=['kazakh', 'russian']))
# Out:
#               precision    recall  f1-score   support
#
#       kazakh       0.88      0.99      0.93      3158
#      russian       0.92      0.99      0.96      5407
#
#    micro avg       0.91      0.99      0.95      8565
#    macro avg       0.90      0.99      0.94      8565
# weighted avg       0.91      0.99      0.95      8565

# %%
# точность
accuracy_score(y_true=sample['manual_tag'], y_pred=sample[f'{METHOD}__best_lang'])
# Out:
# 0.8995554614733277

# %% [markdown]
# #### Q2: Что предсказывается для kz-ru?

# %%
counts_ = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz-ru'])].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
counts_ = (counts_ / exprmnt.df['manual_tag'].value_counts()).fillna(0)

cm = sns.light_palette("orange", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_5e7e6_row0_col0, #T_5e7e6_row2_col0, #T_5e7e6_row3_col0, #T_5e7e6_row5_col0, #T_5e7e6_row7_col0, #T_5e7e6_row8_col0, #T_5e7e6_row9_col0 {
#   background-color: #f3f0ee;
#   color: #000000;
# }
# #T_5e7e6_row1_col0 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_5e7e6_row4_col0 {
#   background-color: #f3f0ed;
#   color: #000000;
# }
# #T_5e7e6_row6_col0 {
#   background-color: #feaa0f;
#   color: #000000;
# }
# </style>
# <table id="T_5e7e6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e7e6_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="index_name level1" >glotlid__best_lang</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e7e6_level0_row0" class="row_heading level0 row0" rowspan="10">kz-ru</th>
#       <th id="T_5e7e6_level1_row0" class="row_heading level1 row0" >bashkir</th>
#       <td id="T_5e7e6_row0_col0" class="data row0 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_5e7e6_level1_row1" class="row_heading level1 row1" >kazakh</th>
#       <td id="T_5e7e6_row1_col0" class="data row1 col0" >0.505725</td>
#     </tr>
#     <tr>
#       <th id="T_5e7e6_level1_row2" class="row_heading level1 row2" >khakas</th>
#       <td id="T_5e7e6_row2_col0" class="data row2 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_5e7e6_level1_row3" class="row_heading level1 row3" >komi-zyrian</th>
#       <td id="T_5e7e6_row3_col0" class="data row3 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_5e7e6_level1_row4" class="row_heading level1 row4" >kyrgyz</th>
#       <td id="T_5e7e6_row4_col0" class="data row4 col0" >0.007634</td>
#     </tr>
#     <tr>
#       <th id="T_5e7e6_level1_row5" class="row_heading level1 row5" >macedonian</th>
#       <td id="T_5e7e6_row5_col0" class="data row5 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_5e7e6_level1_row6" class="row_heading level1 row6" >russian</th>
#       <td id="T_5e7e6_row6_col0" class="data row6 col0" >0.473282</td>
#     </tr>
#     <tr>
#       <th id="T_5e7e6_level1_row7" class="row_heading level1 row7" >southern altai</th>
#       <td id="T_5e7e6_row7_col0" class="data row7 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_5e7e6_level1_row8" class="row_heading level1 row8" >tajik</th>
#       <td id="T_5e7e6_row8_col0" class="data row8 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_5e7e6_level1_row9" class="row_heading level1 row9" >ukrainian</th>
#       <td id="T_5e7e6_row9_col0" class="data row9 col0" >0.001908</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Для csw-текстов предсказывается в основном либо казахский, либо русский -- 50% и 47%.

# %% [markdown]
# #### Q3: Как хорошо метод предсказывает одноязычные тексты на нерелевантных языках?

# %%
# качество бинарной классификации для определения тега unk
sample = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz', 'ru', 'unk', 'skz'])]
y_true = (sample['manual_tag']=='unk').astype(int)
y_pred = (~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian'])).astype(int)

print(classification_report(y_true=y_true, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      8739
#            1       0.17      0.93      0.28        43
#
#     accuracy                           0.98      8782
#    macro avg       0.58      0.95      0.64      8782
# weighted avg       1.00      0.98      0.98      8782

# %%
# какие языки предсказываются для unk
sample[(sample['manual_tag']=='unk')].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  glotlid__best_lang
# unk         abkhazian              1
#             bulgarian              1
#             chuvash                1
#             kazakh                 2
#             komi-zyrian            1
#             kumyk                  1
#             kyrgyz                 9
#             northern uzbek        10
#             old russian            1
#             russian                1
#             tajik                  1
#             tatar                  1
#             ukrainian              7
#             yakut                  6
# Name: text, dtype: int64

# %%
# для каких true тегов предсказывается "другой язык"
sample[(~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  glotlid__best_lang
# kz          bashkir                4
#             belarusian             1
#             halh mongolian         2
#             kalmyk                 1
#             kara-kalpak            1
#             khakas                 1
#             kyrgyz                 2
#             mbf_latn               1
#             tajik                  1
#             tatar                  1
#             vlax romani            1
# ru          anp_deva               1
#             bulgarian              8
#             eastern mari           1
#             karachay-balkar        1
#             khakas                 5
#             kyrgyz                 1
#             nogai                  1
#             old russian           20
#             serbian                2
#             southern altai         1
#             ukrainian              3
#             und                    2
#             yakut                  4
# skz         bashkir                1
#             eastern mari           2
#             gagauz                 2
#             kara-kalpak            4
#             kyrgyz                89
#             moksha                 1
#             nogai                 15
#             northern uzbek         2
#             southern altai         7
#             tatar                  6
#             turkmen                1
#             tuvinian               3
#             western mari           1
# unk         abkhazian              1
#             bulgarian              1
#             chuvash                1
#             komi-zyrian            1
#             kumyk                  1
#             kyrgyz                 9
#             northern uzbek        10
#             old russian            1
#             tajik                  1
#             tatar                  1
#             ukrainian              7
#             yakut                  6
# Name: text, dtype: int64

# %% [markdown]
# Из всех текстов на нерелевантных языках метод выявил всего 93%. 17% из всех текстов, определенных как "нерелевантные" на самом деле содержат казахский или русский.
#
# Что касается ошибочного определения языка, чаще всего русский определяется как древнерусский, "упрощенное" написание казахского принимается за киргизский или ногайский язык.

# %% [markdown]
# #### Q4: Какие результаты для skz?

# %%
# какие языки определены для skz
y_pred = exprmnt.df[(exprmnt.df['manual_tag']=='skz')][f'{METHOD}__best_lang']

y_pred.value_counts() / len(y_pred)
# Out:
# glotlid__best_lang
# kyrgyz            0.511494
# kazakh            0.224138
# nogai             0.086207
# southern altai    0.040230
# tatar             0.034483
# kara-kalpak       0.022989
# tuvinian          0.017241
# gagauz            0.011494
# eastern mari      0.011494
# northern uzbek    0.011494
# moksha            0.005747
# western mari      0.005747
# russian           0.005747
# turkmen           0.005747
# bashkir           0.005747
# Name: count, dtype: float64

# %% [markdown]
# Для текстов, помеченных тегом skz в половине случаев (51%) предсказывается киргизский, в 22% -- казахский.

# %% [markdown]
# #### Q5: Что получим после фильтрации?

# %%
y_pred = exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']).astype(int)

# доля тегов, которые будут выкинуты
counts_ = (exprmnt.df[y_pred==0]['manual_tag'].value_counts() / exprmnt.df['manual_tag'].value_counts()).fillna(0).rename('will_be_excluded, %')

cm = sns.light_palette("green", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_a2faf_row0_col0 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_a2faf_row1_col0 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_a2faf_row2_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_a2faf_row3_col0, #T_a2faf_row4_col0 {
#   background-color: #e9f2e9;
#   color: #000000;
# }
# #T_a2faf_row5_col0 {
#   background-color: #b5d9b5;
#   color: #000000;
# }
# #T_a2faf_row6_col0 {
#   background-color: #289428;
#   color: #f1f1f1;
# }
# #T_a2faf_row7_col0 {
#   background-color: #acd4ac;
#   color: #000000;
# }
# #T_a2faf_row8_col0 {
#   background-color: #42a042;
#   color: #f1f1f1;
# }
# #T_a2faf_row9_col0 {
#   background-color: #6db56d;
#   color: #f1f1f1;
# }
# #T_a2faf_row10_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a2faf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2faf_level0_col0" class="col_heading level0 col0" >will_be_excluded, %</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2faf_level0_row0" class="row_heading level0 row0" >kz</th>
#       <td id="T_a2faf_row0_col0" class="data row0 col0" >0.005066</td>
#     </tr>
#     <tr>
#       <th id="T_a2faf_level0_row1" class="row_heading level0 row1" >kz-ru</th>
#       <td id="T_a2faf_row1_col0" class="data row1 col0" >0.020992</td>
#     </tr>
#     <tr>
#       <th id="T_a2faf_level0_row2" class="row_heading level0 row2" >kz-ru-unk</th>
#       <td id="T_a2faf_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a2faf_level0_row3" class="row_heading level0 row3" >kz-unk</th>
#       <td id="T_a2faf_row3_col0" class="data row3 col0" >0.008850</td>
#     </tr>
#     <tr>
#       <th id="T_a2faf_level0_row4" class="row_heading level0 row4" >ru</th>
#       <td id="T_a2faf_row4_col0" class="data row4 col0" >0.009247</td>
#     </tr>
#     <tr>
#       <th id="T_a2faf_level0_row5" class="row_heading level0 row5" >ru-unk</th>
#       <td id="T_a2faf_row5_col0" class="data row5 col0" >0.211268</td>
#     </tr>
#     <tr>
#       <th id="T_a2faf_level0_row6" class="row_heading level0 row6" >skz</th>
#       <td id="T_a2faf_row6_col0" class="data row6 col0" >0.770115</td>
#     </tr>
#     <tr>
#       <th id="T_a2faf_level0_row7" class="row_heading level0 row7" >skz-ru</th>
#       <td id="T_a2faf_row7_col0" class="data row7 col0" >0.247312</td>
#     </tr>
#     <tr>
#       <th id="T_a2faf_level0_row8" class="row_heading level0 row8" >skz-ru-unk</th>
#       <td id="T_a2faf_row8_col0" class="data row8 col0" >0.666667</td>
#     </tr>
#     <tr>
#       <th id="T_a2faf_level0_row9" class="row_heading level0 row9" >skz-unk</th>
#       <td id="T_a2faf_row9_col0" class="data row9 col0" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_a2faf_level0_row10" class="row_heading level0 row10" >unk</th>
#       <td id="T_a2faf_row10_col0" class="data row10 col0" >0.930233</td>
#     </tr>
#   </tbody>
# </table>

# %%
# абсолютные количества тегов, которые будут выкинуты
counts_ = exprmnt.df[y_pred==0]['manual_tag'].value_counts().rename('will_be_excluded')
counts_ = pd.concat([counts_,exprmnt.df['manual_tag'].value_counts().rename('total')], axis=1)
counts_.fillna(0)
# Out:
#             will_be_excluded  total
# manual_tag
# skz                    134.0    174
# ru                      50.0   5407
# skz-ru                  46.0    186
# unk                     40.0     43
# kz                      16.0   3158
# ru-unk                  15.0     71
# kz-ru                   11.0    524
# skz-ru-unk               2.0      3
# skz-unk                  2.0      4
# kz-unk                   1.0    113
# kz-ru-unk                0.0     16

# %% [markdown]
# Этот способ позволит избавиться от 93% нерелевантных текстов, затронув около 2% примеров с csw.

# %% [markdown]
# ## Fasttext

# %% [markdown]
# ### Анализ

# %%
METHOD = 'fasttext'

visualize_tags(exprmnt.df, method=METHOD, manual_col='manual_tag')

# %% [markdown]
# #### Q1: Для скольких одноязычных примеров (kz и ru) был правильно определен язык?

# %%
# какие теги предсказываются для текстов на казахском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz']))])
# Out:
# fasttext__best_lang
# kazakh       0.995250
# yue_hant     0.001267
# ukrainian    0.000950
# tatar        0.000317
# kyrgyz       0.000317
# bashkir      0.000317
# chechen      0.000317
# kor_hang     0.000317
# tajik        0.000317
# zho_hans     0.000317
# twi_latn     0.000317
# Name: count, dtype: float64

# %%
# какие теги предсказываются для текстов на русском
exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))][f'{METHOD}__best_lang'].value_counts() / len(exprmnt.df[(exprmnt.df['manual_tag'].isin(['ru']))])
# Out:
# fasttext__best_lang
# russian            0.987239
# ukrainian          0.002219
# chechen            0.001110
# bulgarian          0.001110
# yue_hant           0.000925
# chuvash            0.000740
# belarusian         0.000740
# adyghe             0.000740
# bashkir            0.000555
# tatar              0.000555
# karachay-balkar    0.000555
# serbian            0.000555
# vie_latn           0.000370
# kor_hang           0.000370
# macedonian         0.000370
# halh mongolian     0.000370
# deu_latn           0.000370
# kyrgyz             0.000185
# lvs_latn           0.000185
# ossetic            0.000185
# eng_latn           0.000185
# san_deva           0.000185
# zho_hans           0.000185
# Name: count, dtype: float64

# %% [markdown]
# Recall для казахского значительно почти идеальный -- 0.9953 и 0.9872

# %%
sample = exprmnt.df[(exprmnt.df['manual_tag'].isin(['kz', 'ru'])) | (exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].copy()
sample['manual_tag'] = sample['manual_tag'].replace({'kz': 'kazakh', 'ru': 'russian'})

print(classification_report(y_true=sample['manual_tag'], y_pred=sample[f'{METHOD}__best_lang'], labels=['kazakh', 'russian']))
# Out:
#               precision    recall  f1-score   support
#
#       kazakh       0.87      1.00      0.93      3158
#      russian       0.92      0.99      0.95      5407
#
#    micro avg       0.90      0.99      0.94      8565
#    macro avg       0.89      0.99      0.94      8565
# weighted avg       0.90      0.99      0.94      8565

# %%
# точность
accuracy_score(y_true=sample['manual_tag'], y_pred=sample[f'{METHOD}__best_lang'])
# Out:
# 0.8932069510268562

# %% [markdown]
# #### Q2: Что предсказывается для kz-ru?

# %%
counts_ = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz-ru'])].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
counts_ = (counts_ / exprmnt.df['manual_tag'].value_counts()).fillna(0)

cm = sns.light_palette("orange", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_b502d_row0_col0, #T_b502d_row1_col0, #T_b502d_row3_col0, #T_b502d_row4_col0, #T_b502d_row6_col0, #T_b502d_row7_col0 {
#   background-color: #f3f0ee;
#   color: #000000;
# }
# #T_b502d_row2_col0 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_b502d_row5_col0 {
#   background-color: #fdaf20;
#   color: #000000;
# }
# #T_b502d_row8_col0 {
#   background-color: #f3eee9;
#   color: #000000;
# }
# </style>
# <table id="T_b502d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b502d_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="index_name level1" >fasttext__best_lang</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b502d_level0_row0" class="row_heading level0 row0" rowspan="9">kz-ru</th>
#       <th id="T_b502d_level1_row0" class="row_heading level1 row0" >belarusian</th>
#       <td id="T_b502d_row0_col0" class="data row0 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_b502d_level1_row1" class="row_heading level1 row1" >chechen</th>
#       <td id="T_b502d_row1_col0" class="data row1 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_b502d_level1_row2" class="row_heading level1 row2" >kazakh</th>
#       <td id="T_b502d_row2_col0" class="data row2 col0" >0.520992</td>
#     </tr>
#     <tr>
#       <th id="T_b502d_level1_row3" class="row_heading level1 row3" >kyrgyz</th>
#       <td id="T_b502d_row3_col0" class="data row3 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_b502d_level1_row4" class="row_heading level1 row4" >por_latn</th>
#       <td id="T_b502d_row4_col0" class="data row4 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_b502d_level1_row5" class="row_heading level1 row5" >russian</th>
#       <td id="T_b502d_row5_col0" class="data row5 col0" >0.450382</td>
#     </tr>
#     <tr>
#       <th id="T_b502d_level1_row6" class="row_heading level1 row6" >tajik</th>
#       <td id="T_b502d_row6_col0" class="data row6 col0" >0.003817</td>
#     </tr>
#     <tr>
#       <th id="T_b502d_level1_row7" class="row_heading level1 row7" >tatar</th>
#       <td id="T_b502d_row7_col0" class="data row7 col0" >0.001908</td>
#     </tr>
#     <tr>
#       <th id="T_b502d_level1_row8" class="row_heading level1 row8" >ukrainian</th>
#       <td id="T_b502d_row8_col0" class="data row8 col0" >0.015267</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Для csw-текстов предсказывается в основном либо казахский, либо русский -- 52% и 45%.

# %% [markdown]
# #### Q3: Как хорошо метод предсказывает одноязычные тексты на нерелевантных языках?

# %%
# качество бинарной классификации для определения тега unk
sample = exprmnt.df[exprmnt.df['manual_tag'].isin(['kz', 'ru', 'unk', 'skz'])]
y_true = (sample['manual_tag']=='unk').astype(int)
y_pred = (~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian'])).astype(int)

print(classification_report(y_true=y_true, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      8739
#            1       0.17      0.86      0.28        43
#
#     accuracy                           0.98      8782
#    macro avg       0.58      0.92      0.63      8782
# weighted avg       1.00      0.98      0.99      8782

# %%
# какие языки предсказываются для unk
sample[(sample['manual_tag']=='unk')].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  fasttext__best_lang
# unk         bulgarian               1
#             chuvash                 1
#             kazakh                  1
#             kyrgyz                 15
#             russia buriat           2
#             russian                 5
#             serbian                 1
#             southern altai          1
#             tajik                   3
#             tatar                   3
#             ukrainian              10
# Name: text, dtype: int64

# %%
# для каких true тегов предсказывается "другой язык"
sample[(~sample[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']))].groupby(['manual_tag', f'{METHOD}__best_lang'])['text'].count()
# Out:
# manual_tag  fasttext__best_lang
# kz          bashkir                 1
#             chechen                 1
#             kor_hang                1
#             kyrgyz                  1
#             tajik                   1
#             tatar                   1
#             twi_latn                1
#             ukrainian               3
#             yue_hant                4
#             zho_hans                1
# ru          adyghe                  4
#             bashkir                 3
#             belarusian              4
#             bulgarian               6
#             chechen                 6
#             chuvash                 4
#             deu_latn                2
#             eng_latn                1
#             halh mongolian          2
#             karachay-balkar         3
#             kor_hang                2
#             kyrgyz                  1
#             lvs_latn                1
#             macedonian              2
#             ossetic                 1
#             san_deva                1
#             serbian                 3
#             tatar                   3
#             ukrainian              12
#             vie_latn                2
#             yue_hant                5
#             zho_hans                1
# skz         chechen                 1
#             karachay-balkar         1
#             kyrgyz                 87
#             ossetic                 1
#             southern altai          1
#             tatar                   6
#             udmurt                  1
#             ukrainian               1
#             yue_hant                1
# unk         bulgarian               1
#             chuvash                 1
#             kyrgyz                 15
#             russia buriat           2
#             serbian                 1
#             southern altai          1
#             tajik                   3
#             tatar                   3
#             ukrainian              10
# Name: text, dtype: int64

# %% [markdown]
# Из всех текстов на нерелевантных языках метод выявил всего 86%. 17% из всех текстов, определенных как "нерелевантные" на самом деле содержат казахский или русский.
#
# Для документов на казахском и русском модель редко предсказывала другой язык. Для "упрощенного" казахского предсказывался киргизский

# %% [markdown]
# #### Q4: Какие результаты для skz?

# %%
# какие языки определены для skz
y_pred = exprmnt.df[(exprmnt.df['manual_tag']=='skz')][f'{METHOD}__best_lang']

y_pred.value_counts() / len(y_pred)
# Out:
# fasttext__best_lang
# kyrgyz             0.500000
# kazakh             0.390805
# russian            0.034483
# tatar              0.034483
# ossetic            0.005747
# karachay-balkar    0.005747
# chechen            0.005747
# southern altai     0.005747
# ukrainian          0.005747
# yue_hant           0.005747
# udmurt             0.005747
# Name: count, dtype: float64

# %% [markdown]
# Для текстов, помеченных тегом skz в половине случаев (50%) предсказывается киргизский, в 39% -- казахский.

# %% [markdown]
# #### Q5: Что получим после фильтрации?

# %%
y_pred = exprmnt.df[f'{METHOD}__best_lang'].isin(['kazakh', 'russian']).astype(int)

# доля тегов, которые будут выкинуты
counts_ = (exprmnt.df[y_pred==0]['manual_tag'].value_counts() / exprmnt.df['manual_tag'].value_counts()).fillna(0).rename('will_be_excluded, %')

cm = sns.light_palette("green", as_cmap=True)

s = pd.DataFrame(counts_).style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_fcaf4_row0_col0 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_fcaf4_row1_col0 {
#   background-color: #e3efe3;
#   color: #000000;
# }
# #T_fcaf4_row2_col0, #T_fcaf4_row3_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_fcaf4_row4_col0 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_fcaf4_row5_col0, #T_fcaf4_row7_col0 {
#   background-color: #b9dbb9;
#   color: #000000;
# }
# #T_fcaf4_row6_col0 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_fcaf4_row8_col0 {
#   background-color: #349a34;
#   color: #f1f1f1;
# }
# #T_fcaf4_row9_col0 {
#   background-color: #1d8e1d;
#   color: #f1f1f1;
# }
# #T_fcaf4_row10_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fcaf4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcaf4_level0_col0" class="col_heading level0 col0" >will_be_excluded, %</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >manual_tag</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcaf4_level0_row0" class="row_heading level0 row0" >kz</th>
#       <td id="T_fcaf4_row0_col0" class="data row0 col0" >0.004750</td>
#     </tr>
#     <tr>
#       <th id="T_fcaf4_level0_row1" class="row_heading level0 row1" >kz-ru</th>
#       <td id="T_fcaf4_row1_col0" class="data row1 col0" >0.028626</td>
#     </tr>
#     <tr>
#       <th id="T_fcaf4_level0_row2" class="row_heading level0 row2" >kz-ru-unk</th>
#       <td id="T_fcaf4_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fcaf4_level0_row3" class="row_heading level0 row3" >kz-unk</th>
#       <td id="T_fcaf4_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fcaf4_level0_row4" class="row_heading level0 row4" >ru</th>
#       <td id="T_fcaf4_row4_col0" class="data row4 col0" >0.012761</td>
#     </tr>
#     <tr>
#       <th id="T_fcaf4_level0_row5" class="row_heading level0 row5" >ru-unk</th>
#       <td id="T_fcaf4_row5_col0" class="data row5 col0" >0.183099</td>
#     </tr>
#     <tr>
#       <th id="T_fcaf4_level0_row6" class="row_heading level0 row6" >skz</th>
#       <td id="T_fcaf4_row6_col0" class="data row6 col0" >0.574713</td>
#     </tr>
#     <tr>
#       <th id="T_fcaf4_level0_row7" class="row_heading level0 row7" >skz-ru</th>
#       <td id="T_fcaf4_row7_col0" class="data row7 col0" >0.182796</td>
#     </tr>
#     <tr>
#       <th id="T_fcaf4_level0_row8" class="row_heading level0 row8" >skz-ru-unk</th>
#       <td id="T_fcaf4_row8_col0" class="data row8 col0" >0.666667</td>
#     </tr>
#     <tr>
#       <th id="T_fcaf4_level0_row9" class="row_heading level0 row9" >skz-unk</th>
#       <td id="T_fcaf4_row9_col0" class="data row9 col0" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_fcaf4_level0_row10" class="row_heading level0 row10" >unk</th>
#       <td id="T_fcaf4_row10_col0" class="data row10 col0" >0.860465</td>
#     </tr>
#   </tbody>
# </table>

# %%
# абсолютные количества тегов, которые будут выкинуты
counts_ = exprmnt.df[y_pred==0]['manual_tag'].value_counts().rename('will_be_excluded')
counts_ = pd.concat([counts_,exprmnt.df['manual_tag'].value_counts().rename('total')], axis=1)
counts_.fillna(0)
# Out:
#             will_be_excluded  total
# manual_tag
# skz                    100.0    174
# ru                      69.0   5407
# unk                     37.0     43
# skz-ru                  34.0    186
# kz                      15.0   3158
# kz-ru                   15.0    524
# ru-unk                  13.0     71
# skz-unk                  3.0      4
# skz-ru-unk               2.0      3
# kz-unk                   0.0    113
# kz-ru-unk                0.0     16

# %% [markdown]
# Этот способ позволит избавиться от 86% нерелевантных текстов, затронув около 3% примеров с csw.

# %% [markdown]
# ## Эксперимент 2. Выявление CSW-текстов на основе порога

# %%
# очищаем от нерелевантных тегов
df = df.drop(df[~df['glotlid__best_lang'].isin(['kazakh', 'russian'])].index)
df['manual_tag'].value_counts()
# Out:
# manual_tag
# ru            5357
# kz            3142
# kz-ru          513
# skz-ru         140
# kz-unk         112
# ru-unk          56
# skz             40
# kz-ru-unk       16
# unk              3
# skz-unk          2
# skz-ru-unk       1
# Name: count, dtype: int64

# %%
# устанавливаем лейблы для истинных значений
y_true = df['manual_tag'].str.contains('kz-ru')

# %%
methods = list(map(lambda x: x.split('__')[0], df.filter(regex='best_lang').columns))
methods.remove('cld3') # не участвует в анализе
methods
# Out:
# ['cld2',
#  'langid',
#  'lingua',
#  'mediapipe',
#  'fast_langdetect',
#  'glotlid',
#  'fasttext',
#  'dict']

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, fbeta_score

# %%
THRESHOLDS = np.arange(0.5, 1.05, 0.05)

def get_best_upper_threshold(method, thresholds, y_true):
    """
    Примеры с переключением кодов определяются на основе максимального значения вероятности казахского или русского языка.
    В одноязычных текстах, как правило, язык имеет вес, близкий к 1, а все остальные -- близки к 0.
    Тогда мы можем предположить, что в двуязычных текстах вероятность одного языка растет за счет за счет понижения вероятности для другого языка.
    """
    best_metrics = {
        'method': method,
        'best_threshold': -1,
        'best_f1': -1,
        'best_precision': -1,
        'best_recall': -1,
    }

    for t in thresholds:
        t = round(t, 2)
        y_preds = (df[[f'{method}__kaz', f'{method}__rus']].max(axis=1) < t) & (df[[f'{method}__kaz', f'{method}__rus']].min(axis=1) > 0)
        f1_ = f1_score(y_true, y_preds, average=None)[1]
        recall_ = recall_score(y_true, y_preds)
        precision_ = precision_score(y_true, y_preds, zero_division=0)
        # print(f'THRESHOLD={t}', f'F1={round(f1_, 4)}', f'precision={round(precision_, 4)}', f'recall={round(recall_, 4)}', sep='\t')
        if f1_ > best_metrics['best_f1']:
            best_metrics['best_f1'] = f1_
            best_metrics['best_threshold'] = t
            best_metrics['best_recall'] = recall_
            best_metrics['best_precision'] = precision_

    print(best_metrics)
    print('='*80)
    return best_metrics

stats = []
for m in methods:
    stats.append(get_best_upper_threshold(m, THRESHOLDS, y_true))
# Out:
# {'method': 'cld2', 'best_threshold': np.float64(1.0), 'best_f1': np.float64(0.13351877607788595), 'best_precision': 0.9795918367346939, 'best_recall': 0.07164179104477612}
# ================================================================================
# {'method': 'langid', 'best_threshold': np.float64(1.0), 'best_f1': np.float64(0.1547945205479452), 'best_precision': 0.14303797468354432, 'best_recall': 0.16865671641791044}
# ================================================================================
# {'method': 'lingua', 'best_threshold': np.float64(0.8), 'best_f1': np.float64(0.15644555694618273), 'best_precision': 0.13469827586206898, 'best_recall': 0.1865671641791045}
# ================================================================================
# {'method': 'mediapipe', 'best_threshold': np.float64(0.95), 'best_f1': np.float64(0.26725775807473084), 'best_precision': 0.23212321232123212, 'best_recall': 0.31492537313432833}
# ================================================================================
# {'method': 'fast_langdetect', 'best_threshold': np.float64(0.95), 'best_f1': np.float64(0.2790981109079829), 'best_precision': 0.23583934088568487, 'best_recall': 0.3417910447761194}
# ================================================================================
# {'method': 'glotlid', 'best_threshold': np.float64(0.95), 'best_f1': np.float64(0.20930232558139536), 'best_precision': 0.2611607142857143, 'best_recall': 0.1746268656716418}
# ================================================================================
# {'method': 'fasttext', 'best_threshold': np.float64(0.95), 'best_f1': np.float64(0.21656976744186046), 'best_precision': 0.21104815864022664, 'best_recall': 0.22238805970149253}
# ================================================================================
# {'method': 'dict', 'best_threshold': np.float64(0.8), 'best_f1': np.float64(0.43902439024390244), 'best_precision': 0.31476683937823835, 'best_recall': 0.7253731343283583}
# ================================================================================

# %%
# Лучшие максимальные пороги
pd.DataFrame(stats)
# Out:
#             method  best_threshold   best_f1  best_precision  best_recall
# 0             cld2            1.00  0.133519        0.979592     0.071642
# 1           langid            1.00  0.154795        0.143038     0.168657
# 2           lingua            0.80  0.156446        0.134698     0.186567
# 3        mediapipe            0.95  0.267258        0.232123     0.314925
# 4  fast_langdetect            0.95  0.279098        0.235839     0.341791
# 5          glotlid            0.95  0.209302        0.261161     0.174627
# 6         fasttext            0.95  0.216570        0.211048     0.222388
# 7             dict            0.80  0.439024        0.314767     0.725373

# %%
THRESHOLDS = np.arange(0, 0.55, 0.05)

def get_best_lower_threshold(method, thresholds):
    """
    В рамках данного подхода решается задача multilabel-классификации: выбираются языки, вероятность которых превышает определенный порог
    """
    best_metrics = {
        'method': method,
        'best_threshold': -1,
        'best_f1': -1,
        'best_precision': -1,
        'best_recall': -1,
    }

    for t in thresholds:
        t = round(t, 2)
        y_preds = (df[f'{method}__kaz'] >= t) & (df[f'{method}__rus'] >= t)
        f1_ = f1_score(y_true, y_preds, average=None)[1]
        recall_ = recall_score(y_true, y_preds)
        precision_ = precision_score(y_true, y_preds, zero_division=0)
        # print(f'THRESHOLD={t}', f'F1={round(f1_, 4)}', f'precision={round(precision_, 4)}', f'recall={round(recall_, 4)}', sep='\t')
        if f1_ > best_metrics['best_f1']:
            best_metrics['best_f1'] = f1_
            best_metrics['best_threshold'] = t
            best_metrics['best_recall'] = recall_
            best_metrics['best_precision'] = precision_

    print(best_metrics)
    print('='*80)
    return best_metrics

stats = []
for m in methods:
    stats.append(get_best_lower_threshold(m, THRESHOLDS))
# Out:
# {'method': 'cld2', 'best_threshold': np.float64(0.0), 'best_f1': np.float64(0.1333068046159968), 'best_precision': 0.07141334470262205, 'best_recall': 1.0}
# ================================================================================
# {'method': 'langid', 'best_threshold': np.float64(0.0), 'best_f1': np.float64(0.1333068046159968), 'best_precision': 0.07141334470262205, 'best_recall': 1.0}
# ================================================================================
# {'method': 'lingua', 'best_threshold': np.float64(0.05), 'best_f1': np.float64(0.1783840503672613), 'best_precision': 0.3003533568904594, 'best_recall': 0.12686567164179105}
# ================================================================================
# {'method': 'mediapipe', 'best_threshold': np.float64(0.0), 'best_f1': np.float64(0.1341475623185504), 'best_precision': 0.07189612619379762, 'best_recall': 1.0}
# ================================================================================
# {'method': 'fast_langdetect', 'best_threshold': np.float64(0.05), 'best_f1': np.float64(0.2013888888888889), 'best_precision': 0.4484536082474227, 'best_recall': 0.12985074626865672}
# ================================================================================
# {'method': 'glotlid', 'best_threshold': np.float64(0.0), 'best_f1': np.float64(0.1333068046159968), 'best_precision': 0.07141334470262205, 'best_recall': 1.0}
# ================================================================================
# {'method': 'fasttext', 'best_threshold': np.float64(0.05), 'best_f1': np.float64(0.14986376021798364), 'best_precision': 0.859375, 'best_recall': 0.08208955223880597}
# ================================================================================
# {'method': 'dict', 'best_threshold': np.float64(0.1), 'best_f1': np.float64(0.5052160953800298), 'best_precision': 0.5044642857142857, 'best_recall': 0.5059701492537313}
# ================================================================================

# %%
# Лучшие минимальные пороги
pd.DataFrame(stats)
# Out:
#             method  best_threshold   best_f1  best_precision  best_recall
# 0             cld2            0.00  0.133307        0.071413     1.000000
# 1           langid            0.00  0.133307        0.071413     1.000000
# 2           lingua            0.05  0.178384        0.300353     0.126866
# 3        mediapipe            0.00  0.134148        0.071896     1.000000
# 4  fast_langdetect            0.05  0.201389        0.448454     0.129851
# 5          glotlid            0.00  0.133307        0.071413     1.000000
# 6         fasttext            0.05  0.149864        0.859375     0.082090
# 7             dict            0.10  0.505216        0.504464     0.505970

# %% [markdown]
# Ни одна из стратегий не дала надежного результата

# %%
sns.set_style("darkgrid", {"axes.facecolor": ".9", 'legend.frameon':True})

# %%
from matplotlib.colors import to_rgba

# %%
df['manual_tag_grouped'] = np.where(df['manual_tag'].isin(['kz', 'ru', 'kz-ru']), df['manual_tag'], 'other')

custom_palette = {
    'kz': to_rgba('tab:blue', alpha=0.3),
    'ru': to_rgba('tab:green', alpha=0.3),
    'other': to_rgba('tab:grey', alpha=0.3),
    'kz-ru': to_rgba('tab:red', alpha=1),
}

fig, ax = plt.subplots(len(methods)//2, 2, figsize=(5*2, 5*4))
ax = ax.flatten()
for i, m in enumerate(methods):
    sns.scatterplot(ax=ax[i], data=df, x=f'{m}__kaz', y=f'{m}__rus', hue='manual_tag_grouped', legend=False if i>0 else True, palette=custom_palette)
    # sns.scatterplot(ax=ax[i], data=df[df['manual_tag']=='kz-ru'], x=f'{m}__kaz', y=f'{m}__rus', c='crimson', alpha=1, legend=False)

    if i==0:
        sns.move_legend(ax[0], title='manual_tag', loc='best', facecolor='white')

    ax[i].set_title(f'Метод {m}')

plt.suptitle('Распределение вероятностей казахского и русского языка для "ручных" тегов kz, ru, kz-ru и др.')
plt.tight_layout(pad=2.0)
plt.show()
plt.savefig('probas.png')
